# %% [markdown]
# # Validation of Results

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 14.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.9.3

# %%
import pandas as pd
from jiwer import wer, cer, wil, wip, mer

# %% [markdown]
# # Get Datasets

# %%
def get_bid_dataset():
      fluxo_1_4 = pd.read_csv('fluxos_1-4_ID_CARD.csv')
      fluxo_5_8 = pd.read_csv('fluxos_5-8_ID_CARD.csv')

      result_BID = pd.concat([fluxo_1_4, fluxo_5_8], ignore_index=True)
      result_filtered_BID = result_BID[result_BID.path != '/content/crop_craft-images/photos/']

      result_filtered_BID['cv2 time'] = result_filtered_BID['cv2 time'].fillna(0)
      result_filtered_BID['prediction time'] = result_filtered_BID['prediction time'].fillna(0)
      result_filtered_BID.loc[:, 'time_total'] = result_filtered_BID['cv2 time'] + result_filtered_BID['prediction time']

      return result_filtered_BID

def get_IIIT5K_dataset():
    fluxo_1_4_IIIT5K = pd.read_csv('fluxos_1-4_IIIT5K.csv')
    fluxo_5_8_IIIT5K = pd.read_csv('fluxos_5-8_IIIT5K.csv')

    result_IIIT5K = pd.concat([fluxo_1_4_IIIT5K, fluxo_5_8_IIIT5K], ignore_index=True)

    result_filtered_IIIT5K = result_IIIT5K

    result_filtered_IIIT5K['cv2 time'] = result_filtered_IIIT5K['cv2 time'].fillna(0)
    result_filtered_IIIT5K['prediction time'] = result_filtered_IIIT5K['prediction time'].fillna(0)

    result_filtered_IIIT5K['time_total'] = result_filtered_IIIT5K['cv2 time'] + result_filtered_IIIT5K['prediction time']

    return result_filtered_IIIT5K


def get_svhn_dataset():

    fluxo_1_4_svhn = pd.read_csv('fluxos_1-4_svhn.csv')
    fluxo_5_8_svhn = pd.read_csv('fluxos_5-8_svhn.csv')

    result_svhn = pd.concat([fluxo_1_4_svhn, fluxo_5_8_svhn], ignore_index=True)

    result_filtered_svhn = result_svhn

    result_filtered_svhn['cv2 time'] = result_filtered_svhn['cv2 time'].fillna(0)
    result_filtered_svhn['prediction time'] = result_filtered_svhn['prediction time'].fillna(0)
    result_filtered_svhn.loc[:, 'time_total'] = result_filtered_svhn['cv2 time'] + result_filtered_svhn['prediction time']

    return result_filtered_svhn


def get_SROEI_dataset():

    fluxo_1_4_SROEI = pd.read_csv('fluxos_1-4_SROIE.csv')
    fluxo_5_8_SROEI = pd.read_csv('fluxos_5-8_SROIE.csv')

    result_SROEI = pd.concat([fluxo_1_4_SROEI, fluxo_5_8_SROEI], ignore_index=True)
    result_filtered_SROEI = result_SROEI

    result_filtered_SROEI['cv2 time'] = result_filtered_SROEI['cv2 time'].fillna(0)
    result_filtered_SROEI['prediction time'] = result_filtered_SROEI['prediction time'].fillna(0)
    result_filtered_SROEI.loc[:, 'time_total'] = result_filtered_SROEI['cv2 time'] + result_filtered_SROEI['prediction time']

    return result_filtered_SROEI

# %% [markdown]
# # Helper functions

# %%
def get_groupby_results(dataset, experiments_lists, fluxo_list, label=''):
      ##########################################
      # 'OpenCV[todos preproc] -> EASYOCR'
      ##########################################

      opencv_easyocr = dataset[dataset['fluxo'] == fluxo_list[0]]

      opencv_easyocr_result = opencv_easyocr.groupby('filter').agg(
          {
              'wer' + label: ['mean', 'std'],
              'cer' + label: ['mean', 'std'],
              'wil' + label: ['mean', 'std'],
              'wip' + label: ['mean', 'std']
          },
      )
      opencv_easyocr_result_df = opencv_easyocr_result.reset_index()
      opencv_easyocr_result_df.columns = ['_'.join(col).strip() for col in opencv_easyocr_result_df.columns.values]
      opencv_easyocr_result_df['fluxo'] = experiments_lists[0]

      ##########################################
      # 'OpenCV[todos preproc] -> Tesseract'
      ##########################################

      opencv_tesseract = dataset[dataset['fluxo'] == fluxo_list[1]]

      opencv_tesseract_result = opencv_tesseract.groupby('filter').agg(
          {
              'wer' + label: ['mean', 'std'],
              'cer' + label: ['mean', 'std'],
              'wil' + label: ['mean', 'std'],
              'wip' + label: ['mean', 'std']
          },
      )
      opencv_tesseract_result = opencv_tesseract_result.reset_index()
      opencv_tesseract_result.columns = ['_'.join(col).strip() for col in opencv_tesseract_result.columns.values]
      opencv_tesseract_result['fluxo'] = experiments_lists[1]


      ##########################################
      # 'CRAFT -> ESRGAN -> OpenCV -> EASYOCR'
      ##########################################

      ersgan_opencv_easyocr = dataset[dataset['fluxo'] == fluxo_list[2]]

      ersgan_opencv_easyocr_result = ersgan_opencv_easyocr.groupby('filter').agg(
          {
              'wer' + label: ['mean', 'std'],
              'cer' + label: ['mean', 'std'],
              'wil' + label: ['mean', 'std'],
              'wip' + label: ['mean', 'std']
          },
      )
      ersgan_opencv_easyocr_result = ersgan_opencv_easyocr_result.reset_index()
      ersgan_opencv_easyocr_result.columns = ['_'.join(col).strip() for col in ersgan_opencv_easyocr_result.columns.values]
      ersgan_opencv_easyocr_result['fluxo'] = experiments_lists[2]

      ##########################################
      # 'CRAFT -> ESRGAN -> OpenCV -> Tesseract'
      ##########################################

      ersgan_opencv_tesseract = dataset[dataset['fluxo'] == fluxo_list[3]]

      ersgan_opencv_tesseract_result  = ersgan_opencv_tesseract.groupby('filter').agg(
          {
              'wer' + label: ['mean', 'std'],
              'cer' + label: ['mean', 'std'],
              'wil' + label: ['mean', 'std'],
              'wip' + label: ['mean', 'std']
          },
      )
      ersgan_opencv_tesseract_result = ersgan_opencv_tesseract_result.reset_index()
      ersgan_opencv_tesseract_result.columns = ['_'.join(col).strip() for col in ersgan_opencv_tesseract_result.columns.values]
      ersgan_opencv_tesseract_result['fluxo'] = experiments_lists[3]

      return opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result


def get_groupby_timeout(dataset, experiments_lists, fluxo_list):
      ##########################################
      # 'OpenCV[todos preproc] -> EASYOCR'
      ##########################################

      opencv_easyocr = dataset[dataset['fluxo'] == fluxo_list[0]]

      opencv_easyocr_time_total = opencv_easyocr.groupby('filter').agg(
          {
              'time_total': ['mean', 'std'],
          }
      )
      opencv_easyocr_time_total = opencv_easyocr_time_total.reset_index()
      opencv_easyocr_time_total.columns = ['_'.join(col).strip() for col in opencv_easyocr_time_total.columns.values]
      opencv_easyocr_time_total['fluxo'] = experiments_lists[0]

      ##########################################
      # 'OpenCV[todos preproc] -> Tesseract'
      ##########################################

      opencv_tesseract = dataset[dataset['fluxo'] == fluxo_list[1]]

      opencv_tesseract_time_total = opencv_tesseract.groupby('filter').agg(
          {
              'time_total': ['mean', 'std'],
          }
      )
      opencv_tesseract_time_total = opencv_tesseract_time_total.reset_index()
      opencv_tesseract_time_total.columns = ['_'.join(col).strip() for col in opencv_tesseract_time_total.columns.values]
      opencv_tesseract_time_total['fluxo'] = experiments_lists[1]


      ##########################################
      # 'CRAFT -> ESRGAN -> OpenCV -> EASYOCR'
      ##########################################

      ersgan_opencv_easyocr = dataset[dataset['fluxo'] == fluxo_list[2]]

      ersgan_opencv_easyocr_time_total = ersgan_opencv_easyocr.groupby('filter').agg(
          {
              'time_total': ['mean', 'std'],
          }
      )
      ersgan_opencv_easyocr_time_total = ersgan_opencv_easyocr_time_total.reset_index()
      ersgan_opencv_easyocr_time_total.columns = ['_'.join(col).strip() for col in ersgan_opencv_easyocr_time_total.columns.values]
      ersgan_opencv_easyocr_time_total['fluxo'] = experiments_lists[2]

      ##########################################
      # 'CRAFT -> ESRGAN -> OpenCV -> Tesseract'
      ##########################################

      ersgan_opencv_tesseract = dataset[dataset['fluxo'] == fluxo_list[3]]

      ersgan_opencv_tesseract_time_total = ersgan_opencv_tesseract.groupby('filter').agg(
          {
              'time_total': ['mean', 'std'],
          }
      )

      ersgan_opencv_tesseract_time_total = ersgan_opencv_tesseract_time_total.reset_index()
      ersgan_opencv_tesseract_time_total.columns = ['_'.join(col).strip() for col in ersgan_opencv_tesseract_time_total.columns.values]
      ersgan_opencv_tesseract_time_total['fluxo'] = experiments_lists[3]

      return opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total

# %% [markdown]
# ## Results with predictions and processed labels

# %%
def get_process_dataset_lowercase(dataset, label):
    dataset = dataset.dropna(subset=[label])
    dataset['prediction'] = dataset['prediction'].fillna('')
    dataset['prediction'] = dataset['prediction'].str.lower()
    dataset[label] = dataset[label].fillna('')
    dataset[label] = dataset[label].str.lower()

    return dataset

def get_metrics_lowercase(data_df, suffix_value, label):

  for index, row in data_df.iterrows():
    data_df.at[index, 'wer' + suffix_value] = wer(row[label], row['prediction'] )
    data_df.at[index, 'cer' + suffix_value] = cer(row[label], row['prediction'] )
    data_df.at[index, 'wil' + suffix_value] = wil(row[label], row['prediction'] )
    data_df.at[index, 'wip' + suffix_value] = wip(row[label], row['prediction'] )
    data_df.at[index, 'mer' + suffix_value] = mer(row[label], row['prediction'] )

  return data_df


def get_process_dataset_without_symbols(dataset, label):
    dataset = dataset.dropna(subset=[label])
    dataset[label] = dataset[label].str.replace(r'[^\w\s]', '', regex=True)
    dataset['prediction'] = dataset['prediction'].fillna('').str.replace(r'[^\w\s]', '', regex=True)
    dataset.dropna(subset=[label], inplace=True)

    return dataset

# %% [markdown]
# ### Validating Regex

# %%
import re
text = 'OLAS, asdf23 4 # $% @\/;., * +asdfEFA9*((%&)) ;.=-'
cleaned_text = re.sub(r'[^\w\s]', '', text)
print(cleaned_text)
# Out:
# OLAS asdf23 4     asdfEFA9

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# # BID - IDENTITY CARD

# %%
result_filtered_BID = get_bid_dataset()
result_filtered_BID
# Out:
#                                         path                filename  \
# 0      /content/crop_craft-images/CNH_Frente  res_00003604_in_01.jpg
# 1      /content/crop_craft-images/CNH_Frente  res_00003604_in_01.jpg
# 2      /content/crop_craft-images/CNH_Frente  res_00003604_in_01.jpg
# 3      /content/crop_craft-images/CNH_Frente  res_00003604_in_01.jpg
# 4      /content/crop_craft-images/CNH_Frente  res_00003604_in_01.jpg
# ...                                      ...                     ...
# 37730  /content/crop_craft-images/CPF_Frente  res_00010904_in_26.jpg
# 37731  /content/crop_craft-images/CPF_Frente  res_00010904_in_26.jpg
# 37732  /content/crop_craft-images/CPF_Frente  res_00010904_in_26.jpg
# 37733  /content/crop_craft-images/CPF_Frente  res_00010904_in_26.jpg
# 37734  /content/crop_craft-images/CPF_Frente  res_00010904_in_26.jpg
#
#                       filter              prediction  cv2 time  \
# 0                   original              {RE2OGECà]  0.000000
# 1            image_full_gray                R2202sca  0.000032
# 2       limiarização_de_otsu               REFTGG ch  0.000020
# 3       limiarização_binária              202t648224  0.000004
# 4                  bilateral                    Kaca  0.001022
# ...                      ...                     ...       ...
# 37730               original              24/06/1965  0.000000
# 37731        image_full_gray  pos MAO Lo TM RS Tejo)  0.000161
# 37732   limiarização_de_otsu  pos MAO Lo TM RS Tejo)  0.000252
# 37733  limiarização_binária                      NaN  0.000027
# 37734              bilateral              24/00/1965  0.015308
#
#        prediction time       words  wer       cer  wil  wip  mer  \
# 0             0.027089   REPUBLICA  1.0  0.888889  1.0  0.0  1.0
# 1             0.022099   REPUBLICA  1.0  0.888889  1.0  0.0  1.0
# 2             0.022274   REPUBLICA  2.0  0.777778  1.0  0.0  1.0
# 3             0.045176   REPUBLICA  1.0  1.111111  1.0  0.0  1.0
# 4             0.046842   REPUBLICA  1.0  1.000000  1.0  0.0  1.0
# ...                ...         ...  ...       ...  ...  ...  ...
# 37730         0.176564  24/06/1965  0.0  0.000000  0.0  1.0  0.0
# 37731         0.137259  24/06/1965  6.0  2.200000  1.0  0.0  1.0
# 37732         0.137163  24/06/1965  6.0  2.200000  1.0  0.0  1.0
# 37733         0.102696  24/06/1965  1.0  1.000000  1.0  0.0  1.0
# 37734         0.138872  24/06/1965  1.0  0.100000  1.0  0.0  1.0
#
#                                         fluxo  time_total
# 0            OpenCV[todos preproc] -> EASYOCR    0.027089
# 1            OpenCV[todos preproc] -> EASYOCR    0.022131
# 2            OpenCV[todos preproc] -> EASYOCR    0.022293
# 3            OpenCV[todos preproc] -> EASYOCR    0.045180
# 4            OpenCV[todos preproc] -> EASYOCR    0.047864
# ...                                       ...         ...
# 37730  CRAFT -> ESRGAN -> OpenCV -> Tesseract    0.176564
# 37731  CRAFT -> ESRGAN -> OpenCV -> Tesseract    0.137419
# 37732  CRAFT -> ESRGAN -> OpenCV -> Tesseract    0.137415
# 37733  CRAFT -> ESRGAN -> OpenCV -> Tesseract    0.102723
# 37734  CRAFT -> ESRGAN -> OpenCV -> Tesseract    0.154180
#
# [33580 rows x 14 columns]

# %% [markdown]
# ## Default - No processing

# %%
result_filtered_BID = get_bid_dataset()

exp_list = ['CRAFT -> OpenCV[todos preproc] -> EASYOCR',
            'CRAFT -> OpenCV[todos preproc] -> Tesseract',
            'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
            'CRAFT -> ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
              'CRAFT -> ESRGAN -> OpenCV -> Tesseract']

# default
opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_BID, exp_list, fluxo_list)
opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total  = get_groupby_timeout(result_filtered_BID, exp_list, fluxo_list)

result_identity_card = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)
result_identity_card_time_total = pd.concat([opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total], ignore_index=True)

#results
display(result_identity_card.style.background_gradient(cmap='coolwarm'))
display(result_identity_card_time_total.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_3d7df_row0_col1, #T_3d7df_row9_col6, #T_3d7df_row9_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_3d7df_row0_col2, #T_3d7df_row0_col4, #T_3d7df_row10_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_3d7df_row0_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_3d7df_row0_col5, #T_3d7df_row15_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_3d7df_row0_col6, #T_3d7df_row0_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_3d7df_row0_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_3d7df_row1_col1, #T_3d7df_row5_col6, #T_3d7df_row5_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_3d7df_row1_col2, #T_3d7df_row1_col3, #T_3d7df_row4_col2, #T_3d7df_row13_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_3d7df_row1_col4, #T_3d7df_row4_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_3d7df_row1_col5, #T_3d7df_row7_col4, #T_3d7df_row9_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_3d7df_row1_col6, #T_3d7df_row1_col8, #T_3d7df_row4_col6, #T_3d7df_row4_col8, #T_3d7df_row8_col3, #T_3d7df_row8_col5, #T_3d7df_row14_col7, #T_3d7df_row17_col1, #T_3d7df_row17_col2, #T_3d7df_row17_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3d7df_row1_col7, #T_3d7df_row9_col5, #T_3d7df_row13_col6, #T_3d7df_row13_col8 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_3d7df_row2_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_3d7df_row2_col2, #T_3d7df_row9_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_3d7df_row2_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_3d7df_row2_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_3d7df_row2_col5 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_3d7df_row2_col6, #T_3d7df_row2_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_3d7df_row2_col7, #T_3d7df_row19_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_3d7df_row3_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_3d7df_row3_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_3d7df_row3_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_3d7df_row3_col4, #T_3d7df_row6_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3d7df_row3_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_3d7df_row3_col6, #T_3d7df_row3_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_3d7df_row3_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_3d7df_row4_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_3d7df_row4_col4, #T_3d7df_row9_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T
col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_8b935_row10_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8b935_row10_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_8b935_row11_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_8b935_row11_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_8b935_row12_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8b935_row12_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_8b935_row13_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_8b935_row14_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8b935_row14_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_8b935_row15_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_8b935_row15_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_8b935_row16_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_8b935_row16_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_8b935_row17_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_8b935_row17_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_8b935_row18_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_8b935_row18_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_8b935_row19_col1, #T_8b935_row19_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b935" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b935_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_8b935_level0_col1" class="col_heading level0 col1" >time_total_mean</th>
#       <th id="T_8b935_level0_col2" class="col_heading level0 col2" >time_total_std</th>
#       <th id="T_8b935_level0_col3" class="col_heading level0 col3" >fluxo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b935_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b935_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_8b935_row0_col1" class="data row0 col1" >0.011580</td>
#       <td id="T_8b935_row0_col2" class="data row0 col2" >0.005168</td>
#       <td id="T_8b935_row0_col3" class="data row0 col3" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b935_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_8b935_row1_col1" class="data row1 col1" >0.012855</td>
#       <td id="T_8b935_row1_col2" class="data row1 col2" >0.003958</td>
#       <td id="T_8b935_row1_col3" class="data row1 col3" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b935_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_8b935_row2_col1" class="data row2 col1" >0.011569</td>
#       <td id="T_8b935_row2_col2" class="data row2 col2" >0.005484</td>
#       <td id="T_8b935_row2_col3" class="data row2 col3" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b935_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_8b935_row3_col1" class="data row3 col1" >0.010267</td>
#       <td id="T_8b935_row3_col2" class="data row3 col2" >0.005390</td>
#       <td id="T_8b935_row3_col3" class="data row3 col3" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b935_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_8b935_row4_col1" class="data row4 col1" >0.014121</td>
#       <td id="T_8b935_row4_col2" class="data row4 col2" >0.010026</td>
#       <td id="T_8b935_row4_col3" class="data row4 col3" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b935_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_8b935_row5_col1" class="data row5 col1" >0.098496</td>
#       <td id="T_8b935_row5_col2" class="data row5 col2" >0.004405</td>
#       <td id="T_8b935_row5_col3" class="data row5 col3" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8b935_row6_col0" class="data row6 col0" >image_full_gray</td>
#       <td id="T_8b935_row6_col1" class="data row6 col1" >0.099411</td>
#       <td id="T_8b935_row6_col2" class="data row6 col2" >0.004800</td>
#       <td id="T_8b935_row6_col3" class="data row6 col3" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8b935_row7_col0" class="data row7 col0" >limiarização_binária </td>
#       <td id="T_8b935_row7_col1" class="data row7 col1" >0.099923</td>
#       <td id="T_8b935_row7_col2" class="data row7 col2" >0.004382</td>
#       <td id="T_8b935_row7_col3" class="data row7 col3" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8b935_row8_col0" class="data row8 col0" >limiarização_de_otsu</td>
#       <td id="T_8b935_row8_col1" class="data row8 col1" >0.099927</td>
#       <td id="T_8b935_row8_col2" class="data row8 col2" >0.005276</td>
#       <td id="T_8b935_row8_col3" class="data row8 col3" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8b935_row9_col0" class="data row9 col0" >original</td>
#       <td id="T_8b935_row9_col1" class="data row9 col1" >0.100483</td>
#       <td id="T_8b935_row9_col2" class="data row9 col2" >0.005211</td>
#       <td id="T_8b935_row9_col3" class="data row9 col3" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8b935_row10_col0" class="data row10 col0" >bilateral</td>
#       <td id="T_8b935_row10_col1" class="data row10 col1" >0.033672</td>
#       <td id="T_8b935_row10_col2" class="data row10 col2" >0.011752</td>
#       <td id="T_8b935_row10_col3" class="data row10 col3" >CRAFT -> ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8b935_row11_col0" class="data row11 col0" >image_full_gray</td>
#       <td id="T_8b935_row11_col1" class="data row11 col1" >0.021738</td>
#       <td id="T_8b935_row11_col2" class="data row11 col2" >0.007811</td>
#       <td id="T_8b935_row11_col3" class="data row11 col3" >CRAFT -> ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8b935_level0_row12" class

# %% [markdown]
# ## Texts in lowercase

# %%
exp_list = ['CRAFT -> OpenCV[todos preproc] -> EASYOCR',
            'CRAFT -> OpenCV[todos preproc] -> Tesseract',
            'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
            'CRAFT -> ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
              'CRAFT -> ESRGAN -> OpenCV -> Tesseract']


# Com textos processados em lowercase
result_lowercase_BID = get_bid_dataset()

result_lowercase_BID = get_process_dataset_lowercase(result_lowercase_BID, 'words')

result_lowercase_BID = get_metrics_lowercase(result_lowercase_BID, '_lowercase', 'words')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_lowercase_BID, exp_list, fluxo_list, '_lowercase')

result_identity_card_lowercase = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_identity_card_lowercase.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_be14b_row0_col1, #T_be14b_row13_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_be14b_row0_col2, #T_be14b_row6_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_be14b_row0_col3, #T_be14b_row12_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_be14b_row0_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_be14b_row0_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_be14b_row0_col6, #T_be14b_row0_col8 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_be14b_row0_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_be14b_row1_col1, #T_be14b_row9_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col2, #T_be14b_row13_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col6, #T_be14b_row1_col8, #T_be14b_row8_col3, #T_be14b_row8_col5, #T_be14b_row10_col7, #T_be14b_row14_col7, #T_be14b_row17_col1, #T_be14b_row17_col2, #T_be14b_row17_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_be14b_row1_col7 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_be14b_row2_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_be14b_row2_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_be14b_row2_col3, #T_be14b_row12_col5 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_be14b_row2_col4, #T_be14b_row3_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_be14b_row2_col5 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_be14b_row2_col6, #T_be14b_row2_col8 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_be14b_row2_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_be14b_row3_col1, #T_be14b_row7_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_be14b_row3_col2, #T_be14b_row5_col6, #T_be14b_row5_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_be14b_row3_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_be14b_row3_col5, #T_be14b_row16_col3, #T_be14b_row18_col3 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_be14b_row3_col6, #T_be14b_row3_col8 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_be14b_row3_col7, #T_be14b_row15_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_be14b_row4_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col3, #T_be14b_row6_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col4, #T_be14b_row5_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col6, #T_be14b_row4_col8 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_be14b_row4_col7 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_be14b_row5_col1, #T_be14b_row16_col1, #T_be14b_row17_col5, #T_be14b_row18_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_be14b_row5_col2, #T_be14b_row8_col6, #T_be14b_row8_col7, #T_be14b_row8_col8, #T_be14b_row10_col5, #T_be14b_row14_col1, #T_be14b_row14_col3, #T_be14b_row14_col4, #T_be14b_row14_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_be14b_row5_col3 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_be14b_row5_col4, #T_be14b_row8_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_be14b_row5_col5 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_be14b_row6_col1 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_be14b_row6_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_be14b_row6_col5, #T_be14b_row13_col6, #T_be14b_row13_col8 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_be14b_row6_col6, #T_be14b_row6_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_be14b_row6_col7, #T_be14b_row11_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_be14b_row7_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_be14b_row7_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_be14b_row7_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_be14b_row7_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_be14b_row7_col6, #T_be14b_row7_col8, #T_be14b_row16_col6, #T_be14b_row16_col8, #T_be14b_row18_col6, #T_be14b_row18_col8 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_be14b_row7_col7, #T_be14b_row12_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_be14b_row8_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_be14b_row8_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_be14b_row9_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_be14b_row9_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_be14b_row9_col4, #T_be14b_row9_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_be14b_row9_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_be14b_row9_col6, #T_be14b_row9_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_be14b_row10_col1, #T_be14b_row11_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_be14b_row10_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_be14b_row10_col3, #T_be14b_row11_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_be14b_row10_col4, #T_be14b_row11_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_be14b_row10_col6, #T_be14b_row10_col8, #T_be14b_row14_col6, #T_be14b_row14_col8 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_be14b_row11_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_be14b_row11_col6, #T_be14b_row11_col8 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_be14b_row11_col7 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_be14b_row12_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_be14b_row12_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_be14b_row12_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_be14b_row12_col6, #T_be14b_row12_col8 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_be14b_row13_col3, #T_be14b_row13_col5 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_be14b_row13_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_be14b_row13_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_be14b_row14_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_be14b_row15_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_be14b_row15_col3 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_be14b_row15_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_be14b_row15_col5 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_be14b_row15_col6, #T_be14b_row15_col8 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_be14b_row15_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_be14b_row16_col2, #T_be14b_row18_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_be14b_row16_col4, #T_be14b_row18_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_be14b_row16_col5, #T_be14b_row18_col5 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_be14b_row16_col7, #T_be14b_row18_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_be14b_row17_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_be14b_row17_col6, #T_be14b_row17_col8 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_be14b_row17_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_be14b_row19_col1 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_be14b_row19_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_be14b_row19_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_be14b_row19_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_be14b_row19_col5, #T_be14b_row19_col6, #T_be14b_row19_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_be14b_row19_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# </style>
# <table id="T_be14b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0

# %% [markdown]
# ## Texts in lowercase and removed special characters and punctuations

# %%
import numpy as np

exp_list = ['CRAFT -> OpenCV[todos preproc] -> EASYOCR',
            'CRAFT -> OpenCV[todos preproc] -> Tesseract',
            'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
            'CRAFT -> ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'CRAFT -> ESRGAN -> OpenCV -> EASYOCR',
              'CRAFT -> ESRGAN -> OpenCV -> Tesseract']


# Com textos processados em lowercase
result_lowercase_BID = get_bid_dataset()

result_lowercase_BID = get_process_dataset_lowercase(result_lowercase_BID, 'words')
result_lowercase_BID = get_process_dataset_without_symbols(result_lowercase_BID, 'words')
result_lowercase_BID['words'] = result_lowercase_BID['words'].apply(lambda x: None if x.isspace() else x)
result_lowercase_BID.dropna(subset=['words'], inplace=True)

result_lowercase_BID = get_metrics_lowercase(result_lowercase_BID, '_no_schar', 'words')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_lowercase_BID, exp_list, fluxo_list, '_no_schar')

result_identity_card_lowercase_no_special = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_identity_card_lowercase_no_special.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_8c9fb_row0_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_8c9fb_row0_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8c9fb_row0_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8c9fb_row0_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_8c9fb_row0_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_8c9fb_row0_col6, #T_8c9fb_row0_col8, #T_8c9fb_row4_col6, #T_8c9fb_row4_col8 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_8c9fb_row0_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_8c9fb_row1_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col2, #T_8c9fb_row13_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col5, #T_8c9fb_row8_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col6, #T_8c9fb_row1_col8, #T_8c9fb_row8_col3, #T_8c9fb_row8_col5, #T_8c9fb_row10_col7, #T_8c9fb_row12_col6, #T_8c9fb_row12_col8, #T_8c9fb_row17_col1, #T_8c9fb_row17_col2, #T_8c9fb_row17_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8c9fb_row1_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_8c9fb_row2_col1, #T_8c9fb_row6_col6, #T_8c9fb_row6_col8 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_8c9fb_row2_col2, #T_8c9fb_row10_col2, #T_8c9fb_row14_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_8c9fb_row2_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_8c9fb_row2_col4, #T_8c9fb_row12_col4, #T_8c9fb_row19_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_8c9fb_row2_col5 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_8c9fb_row2_col6, #T_8c9fb_row2_col8 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_8c9fb_row2_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_8c9fb_row3_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_8c9fb_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_8c9fb_row3_col3, #T_8c9fb_row16_col5, #T_8c9fb_row18_col5 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_8c9fb_row3_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_8c9fb_row3_col5, #T_8c9fb_row15_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_8c9fb_row3_col6, #T_8c9fb_row3_col8 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_8c9fb_row3_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_8c9fb_row4_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_8c9fb_row4_col2, #T_8c9fb_row7_col2, #T_8c9fb_row8_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_8c9fb_row4_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_8c9fb_row4_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_8c9fb_row4_col5, #T_8c9fb_row6_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_8c9fb_row4_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col2, #T_8c9fb_row8_col6, #T_8c9fb_row8_col7, #T_8c9fb_row8_col8, #T_8c9fb_row10_col1, #T_8c9fb_row10_col3, #T_8c9fb_row10_col4, #T_8c9fb_row10_col5, #T_8c9fb_row14_col3, #T_8c9fb_row14_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col3, #T_8c9fb_row11_col7 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col5, #T_8c9fb_row13_col6, #T_8c9fb_row13_col8 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col6, #T_8c9fb_row5_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_8c9fb_row5_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_8c9fb_row6_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_8c9fb_row6_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_8c9fb_row6_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_8c9fb_row6_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_8c9fb_row6_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8c9fb_row7_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_8c9fb_row7_col3, #T_8c9fb_row16_col1, #T_8c9fb_row18_col1, #T_8c9fb_row19_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_8c9fb_row7_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_8c9fb_row7_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_8c9fb_row7_col6, #T_8c9fb_row7_col8 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_8c9fb_row7_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_8c9fb_row8_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_8c9fb_row9_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_8c9fb_row9_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_8c9fb_row9_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_8c9fb_row9_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_8c9fb_row9_col5 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8c9fb_row9_col6, #T_8c9fb_row9_col8, #T_8c9fb_row19_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_8c9fb_row9_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8c9fb_row10_col6, #T_8c9fb_row10_col8 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_8c9fb_row11_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_8c9fb_row11_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8c9fb_row11_col3, #T_8c9fb_row11_col4, #T_8c9fb_row14_col1, #T_8c9fb_row14_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8c9fb_row11_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_8c9fb_row11_col6, #T_8c9fb_row11_col8 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_8c9fb_row12_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_8c9fb_row12_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_8c9fb_row12_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_8c9fb_row12_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8c9fb_row12_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_8c9fb_row13_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_8c9fb_row13_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_8c9fb_row13_col4, #T_8c9fb_row15_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_8c9fb_row13_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_8c9fb_row13_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_8c9fb_row14_col6, #T_8c9fb_row14_col8 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_8c9fb_row14_col7 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_8c9fb_row15_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_8c9fb_row15_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_8c9fb_row15_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_8c9fb_row15_col5 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_8c9fb_row15_col6, #T_8c9fb_row15_col8 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_8c9fb_row16_col2, #T_8c9fb_row18_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_8c9fb_row16_col3, #T_8c9fb_row18_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_8c9fb_row16_col4, #T_8c9fb_row18_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_8c9fb_row16_col6, #T_8c9fb_row16_col8, #T_8c9fb_row18_col6, #T_8c9fb_row18_col8 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_8c9fb_row16_col7, #T_8c9fb_row18_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_8c9fb_row17_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_8c9fb_row17_col5, #T_8c9fb_row19_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_8c9fb_row17_col6, #T_8c9fb_row17_col8 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_8c9fb_row17_col7, #T_8c9fb_row19_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_8c9fb_row19_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8c9fb_row19_col6, #T_8c9fb_row19_col8 {
#   background-color: #d85646;
#   color: #f1f1f1

# %% [markdown]
# # IIIT5K

# %%
result_filtered_IIIT5K = get_IIIT5K_dataset()
result_filtered_IIIT5K.head(50)
# Out:
#                             path    filename                filter prediction  \
# 0   /content/IIIT5K/IIIT5K/test/  1002_1.png              original    PRIVATE
# 1   /content/IIIT5K/IIIT5K/test/  1002_1.png       image_full_gray    PRIVATE
# 2   /content/IIIT5K/IIIT5K/test/  1002_1.png  limiarização_de_otsu    PRIVATE
# 3   /content/IIIT5K/IIIT5K/test/  1002_1.png  limiarização_binária    PRIVATE
# 4   /content/IIIT5K/IIIT5K/test/  1002_1.png             bilateral    PRIVATE
# 5   /content/IIIT5K/IIIT5K/test/  1002_2.png              original    PARKING
# 6   /content/IIIT5K/IIIT5K/test/  1002_2.png       image_full_gray    PARKING
# 7   /content/IIIT5K/IIIT5K/test/  1002_2.png  limiarização_de_otsu    PARKING
# 8   /content/IIIT5K/IIIT5K/test/  1002_2.png  limiarização_binária    PARKING
# 9   /content/IIIT5K/IIIT5K/test/  1002_2.png             bilateral    PARKING
# 10  /content/IIIT5K/IIIT5K/test/  1009_1.png              original    Salutes
# 11  /content/IIIT5K/IIIT5K/test/  1009_1.png       image_full_gray    Salutes
# 12  /content/IIIT5K/IIIT5K/test/  1009_1.png  limiarização_de_otsu     alutes
# 13  /content/IIIT5K/IIIT5K/test/  1009_1.png  limiarização_binária    balutes
# 14  /content/IIIT5K/IIIT5K/test/  1009_1.png             bilateral    Salules
# 15  /content/IIIT5K/IIIT5K/test/   100_1.png              original      DOLCE
# 16  /content/IIIT5K/IIIT5K/test/   100_1.png       image_full_gray      DOLCE
# 17  /content/IIIT5K/IIIT5K/test/   100_1.png  limiarização_de_otsu      DOLCE
# 18  /content/IIIT5K/IIIT5K/test/   100_1.png  limiarização_binária      DOLCE
# 19  /content/IIIT5K/IIIT5K/test/   100_1.png             bilateral       DOCE
# 20  /content/IIIT5K/IIIT5K/test/   100_2.png              original    CABBANA
# 21  /content/IIIT5K/IIIT5K/test/   100_2.png       image_full_gray    CABBANA
# 22  /content/IIIT5K/IIIT5K/test/   100_2.png  limiarização_de_otsu    GABBANA
# 23  /content/IIIT5K/IIIT5K/test/   100_2.png  limiarização_binária    GABBANA
# 24  /content/IIIT5K/IIIT5K/test/   100_2.png             bilateral    GABBANA
# 25  /content/IIIT5K/IIIT5K/test/   100_3.png              original    REGENCY
# 26  /content/IIIT5K/IIIT5K/test/   100_3.png       image_full_gray    REGENCY
# 27  /content/IIIT5K/IIIT5K/test/   100_3.png  limiarização_de_otsu    RE#ENCY
# 28  /content/IIIT5K/IIIT5K/test/   100_3.png  limiarização_binária         Rk
# 29  /content/IIIT5K/IIIT5K/test/   100_3.png             bilateral    REGENCY
# 30  /content/IIIT5K/IIIT5K/test/  1016_1.png              original       SILE
# 31  /content/IIIT5K/IIIT5K/test/  1016_1.png       image_full_gray       SIAE
# 32  /content/IIIT5K/IIIT5K/test/  1016_1.png  limiarização_de_otsu        NaN
# 33  /content/IIIT5K/IIIT5K/test/  1016_1.png  limiarização_binária        NaN
# 34  /content/IIIT5K/IIIT5K/test/  1016_1.png             bilateral        NaN
# 35  /content/IIIT5K/IIIT5K/test/  1016_2.png              original       BEnI
# 36  /content/IIIT5K/IIIT5K/test/  1016_2.png       image_full_gray        NaN
# 37  /content/IIIT5K/IIIT5K/test/  1016_2.png  limiarização_de_otsu      EANRC
# 38  /content/IIIT5K/IIIT5K/test/  1016_2.png  limiarização_binária        NaN
# 39  /content/IIIT5K/IIIT5K/test/  1016_2.png             bilateral        NaN
# 40  /content/IIIT5K/IIIT5K/test/  1016_3.png              original        NaN
# 41  /content/IIIT5K/IIIT5K/test/  1016_3.png       image_full_gray        NaN
# 42  /content/IIIT5K/IIIT5K/test/  1016_3.png  limiarização_de_otsu         Q;
# 43  /content/IIIT5K/IIIT5K/test/  1016_3.png  limiarização_binária        NaN
# 30  0.000000         0.082755    STATE  1.0  0.600000  1.0  0.0  1.0
# 31  0.000020         0.012105    STATE  1.0  0.400000  1.0  0.0  1.0
# 32  0.000016         0.005466    STATE  1.0  1.000000  1.0  0.0  1.0
# 33  0.000004         0.005512    STATE  1.0  1.000000  1.0  0.0  1.0
# 34  0.000281         0.005384    STATE  1.0  1.000000  1.0  0.0  1.0
# 35  0.000000         0.081180     BANK  1.0  0.750000  1.0  0.0  1.0
# 36  0.000023         0.005697     BANK  1.0  1.000000  1.0  0.0  1.0
# 37  0.000015         0.018236     BANK  1.0  0.750000  1.0  0.0  1.0
# 38  0.000004         0.005265     BANK  1.0  1.000000  1.0  0.0  1.0
# 39  0.000236         0.005311     BANK  1.0  1.000000  1.0  0.0  1.0
# 40  0.000000         0.083963       OF  1.0  1.000000  1.0  0.0  1.0
# 41  0.000011         0.005644       OF  1.0  1.000000  1.0  0.0  1.0
# 42  0.000012         0.017140       OF  1.0  1.000000  1.0  0.0  1.0
# 43  0.000003         0.005316       OF  1.0  1.000000  1.0  0.0  1.0
# 44  0.000133         0.005157       OF  1.0  1.000000  1.0  0.0  1.0
# 45  0.000000         0.005205    INDIA  1.0  1.000000  1.0  0.0  1.0
# 46  0.000010         0.005157    INDIA  1.0  1.000000  1.0  0.0  1.0
# 47  0.000011         0.010804    INDIA  1.0  1.000000  1.0  0.0  1.0
# 48  0.000003         0.005152    INDIA  1.0  1.000000  1.0  0.0  1.0
# 49  0.000204         0.005109    INDIA  1.0  1.000000  1.0  0.0  1.0
#
#                                fluxo  time_total
# 0   OpenCV[todos preproc] -> EASYOCR    0.122835
# 1   OpenCV[todos preproc] -> EASYOCR    0.014207
# 2   OpenCV[todos preproc] -> EASYOCR    0.013867
# 3   OpenCV[todos preproc] -> EASYOCR    0.013540
# 4   OpenCV[todos preproc] -> EASYOCR    0.014740
# 5   OpenCV[todos preproc] -> EASYOCR    0.092546
# 6   OpenCV[todos preproc] -> EASYOCR    0.014175
# 7   OpenCV[todos preproc] -> EASYOCR    0.013752
# 8   OpenCV[todos preproc] -> EASYOCR    0.013551
# 9   OpenCV[todos preproc] -> EASYOCR    0.014405
# 10  OpenCV[todos preproc] -> EASYOCR    0.113929
# 11  OpenCV[todos preproc] -> EASYOCR    0.012965
# 12  OpenCV[todos preproc] -> EASYOCR    0.035739
# 13  OpenCV[todos preproc] -> EASYOCR    0.012653
# 14  OpenCV[todos preproc] -> EASYOCR    0.013172
# 15  OpenCV[todos preproc] -> EASYOCR    0.090467
# 16  OpenCV[todos preproc] -> EASYOCR    0.012404
# 17  OpenCV[todos preproc] -> EASYOCR    0.012053
# 18  OpenCV[todos preproc] -> EASYOCR    0.012030
# 19  OpenCV[todos preproc] -> EASYOCR    0.012470
# 20  OpenCV[todos preproc] -> EASYOCR    0.092424
# 21  OpenCV[todos preproc] -> EASYOCR    0.013682
# 22  OpenCV[todos preproc] -> EASYOCR    0.013577
# 23  OpenCV[todos preproc] -> EASYOCR    0.022468
# 24  OpenCV[todos preproc] -> EASYOCR    0.016045
# 25  OpenCV[todos preproc] -> EASYOCR    0.043156
# 26  OpenCV[todos preproc] -> EASYOCR    0.016060
# 27  OpenCV[todos preproc] -> EASYOCR    0.015127
# 28  OpenCV[todos preproc] -> EASYOCR    0.020657
# 29  OpenCV[todos preproc] -> EASYOCR    0.016628
# 30  OpenCV[todos preproc] -> EASYOCR    0.082755
# 31  OpenCV[todos preproc] -> EASYOCR    0.012125
# 32  OpenCV[todos preproc] -> EASYOCR    0.005481
# 33  OpenCV[todos preproc] -> EASYOCR    0.005516
# 34  OpenCV[todos preproc] -> EASYOCR    0.005666
# 35  OpenCV[todos preproc] -> EASYOCR    0.081180
# 36  OpenCV[todos preproc] -> EASYOCR    0.005719
# 37  OpenCV[todos preproc] -> EASYOCR    0.018251
# 38  OpenCV[todos preproc] -> EASYOCR    0.005268
# 39  OpenCV[todos preproc] -> EASYOCR    0.005546
# 40  OpenCV[todos preproc] -> EASYOCR    0.083963
# 41  OpenCV[todos preproc] -> EASYOCR    0.005655
# 42  OpenCV[todos preproc] -> EASYOCR    0.017152
# 43  OpenCV[todos preproc] -> EASYOCR    0.005319
# 44  OpenCV[todos preproc] -> EASYOCR    0.005290
# 45  OpenCV[todos preproc] -> EASYOCR    0.005205
# 46  OpenCV[todos preproc] -> EASYOCR    0.005167
# 47  OpenCV[todos preproc] -> EASYOCR    0.010816
# 48  OpenCV[todos preproc] -> EASYOCR    0.005155
# 49  OpenCV[todos preproc] -> EASYOCR    0.005313

# %% [markdown]
# ### Default - No processing

# %%
result_filtered_IIIT5K = get_IIIT5K_dataset()

exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_IIIT5K, exp_list, fluxo_list)

opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total  = get_groupby_timeout(result_filtered_IIIT5K, exp_list, fluxo_list)

result_IIIT5K = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)
result_IIIT5K_time_total = pd.concat([opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total], ignore_index=True)

display(result_IIIT5K.style.background_gradient(cmap='coolwarm'))
display(result_IIIT5K_time_total.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_288a9_row0_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_288a9_row0_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_288a9_row0_col3, #T_288a9_row19_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_288a9_row0_col4, #T_288a9_row6_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_288a9_row0_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_288a9_row0_col6, #T_288a9_row0_col8, #T_288a9_row12_col6, #T_288a9_row12_col8 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_288a9_row0_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_288a9_row1_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_288a9_row1_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_288a9_row1_col3, #T_288a9_row4_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_288a9_row1_col4, #T_288a9_row3_col1, #T_288a9_row4_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_288a9_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_288a9_row1_col6, #T_288a9_row1_col8 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_288a9_row1_col7, #T_288a9_row6_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_288a9_row2_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_288a9_row2_col2, #T_288a9_row7_col4, #T_288a9_row12_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_288a9_row2_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_288a9_row2_col4, #T_288a9_row6_col2, #T_288a9_row8_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_288a9_row2_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_288a9_row2_col6, #T_288a9_row2_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_288a9_row2_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_288a9_row3_col2, #T_288a9_row3_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_288a9_row3_col3, #T_288a9_row12_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_288a9_row3_col4, #T_288a9_row13_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_288a9_row3_col6, #T_288a9_row3_col8 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_288a9_row3_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_288a9_row4_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_288a9_row4_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_288a9_row4_col5, #T_288a9_row7_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_288a9_row4_col6, #T_288a9_row4_col8, #T_288a9_row5_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_288a9_row4_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_288a9_row5_col1, #T_288a9_row6_col1 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_288a9_row5_col2, #T_288a9_row5_col4, #T_288a9_row7_col6, #T_288a9_row7_col7, #T_288a9_row7_col8, #T_288a9_row10_col1, #T_288a9_row10_col5, #T_288a9_row11_col5, #T_288a9_row14_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_288a9_row5_col3, #T_288a9_row7_col1, #T_288a9_row13_col6, #T_288a9_row13_col8 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_288a9_row5_col6, #T_288a9_row5_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_288a9_row5_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_288a9_row6_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_288a9_row6_col6, #T_288a9_row6_col8, #T_288a9_row11_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_288a9_row6_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_288a9_row7_col3, #T_288a9_row7_col5, #T_288a9_row10_col6, #T_288a9_row10_col7, #T_288a9_row10_col8, #T_288a9_row11_col6, #T_288a9_row11_col7, #T_288a9_row11_col8, #T_288a9_row14_col6, #T_288a9_row14_col8, #T_288a9_row17_col1, #T_288a9_row19_col2, #T_288a9_row19_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col3 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col4, #T_288a9_row12_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col5, #T_288a9_row13_col7 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col6, #T_288a9_row8_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_288a9_row8_col7, #T_288a9_row13_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_288a9_row9_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col6, #T_288a9_row9_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_288a9_row9_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_288a9_row10_col2, #T_288a9_row10_col4, #T_288a9_row14_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_288a9_row10_col3, #T_288a9_row14_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_288a9_row11_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_288a9_row11_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_288a9_row11_col4, #T_288a9_row13_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_288a9_row12_col1, #T_288a9_row15_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_288a9_row12_col5, #T_288a9_row17_col6, #T_288a9_row17_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_288a9_row12_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_288a9_row13_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_288a9_row13_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_288a9_row14_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_288a9_row14_col2, #T_288a9_row17_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_288a9_row14_col7 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_288a9_row15_col1 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_288a9_row15_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_288a9_row15_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_288a9_row15_col4 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_288a9_row15_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_288a9_row15_col6, #T_288a9_row15_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_288a9_row16_col1, #T_288a9_row18_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_288a9_row16_col2, #T_288a9_row18_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_288a9_row16_col3, #T_288a9_row17_col5, #T_288a9_row18_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_288a9_row16_col4, #T_288a9_row18_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_288a9_row16_col5, #T_288a9_row18_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_288a9_row16_col6, #T_288a9_row16_col8, #T_288a9_row18_col6, #T_288a9_row18_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_288a9_row16_col7, #T_288a9_row18_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_288a9_row17_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_288a9_row17_col3 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_288a9_row17_col4 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_288a9_row19_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_288a9_row19_col3 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_288a9_row19_col5 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_288a9_row19_col6, #T_288a9_row19_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_288a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_288a9_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_288a9_level0_col1" class="col_heading level0 col1" >wer_mean</th>
#       <th id="T_288a9_level0_col2" class="col_heading level0 col2" >wer_std</th>
#       <th id="T_288a9_level0_col3" class=
# <style type="text/css">
# #T_4a796_row0_col1, #T_4a796_row1_col1, #T_4a796_row3_col1, #T_4a796_row7_col2, #T_4a796_row8_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4a796_row0_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4a796_row1_col2, #T_4a796_row2_col1, #T_4a796_row2_col2, #T_4a796_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4a796_row4_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_4a796_row4_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_4a796_row5_col1, #T_4a796_row6_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_4a796_row5_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_4a796_row6_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_4a796_row7_col1, #T_4a796_row8_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_4a796_row9_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_4a796_row9_col2, #T_4a796_row16_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_4a796_row10_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_4a796_row10_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4a796_row11_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4a796_row11_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4a796_row12_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4a796_row12_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4a796_row13_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_4a796_row13_col2, #T_4a796_row14_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4a796_row14_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4a796_row15_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_4a796_row15_col2 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_4a796_row16_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_4a796_row17_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_4a796_row17_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_4a796_row18_col1 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_4a796_row18_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_4a796_row19_col1, #T_4a796_row19_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a796" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a796_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_4a796_level0_col1" class="col_heading level0 col1" >time_total_mean</th>
#       <th id="T_4a796_level0_col2" class="col_heading level0 col2" >time_total_std</th>
#       <th id="T_4a796_level0_col3" class="col_heading level0 col3" >fluxo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a796_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a796_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_4a796_row0_col1" class="data row0 col1" >0.012939</td>
#       <td id="T_4a796_row0_col2" class="data row0 col2" >0.010043</td>
#       <td id="T_4a796_row0_col3" class="data row0 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a796_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_4a796_row1_col1" class="data row1 col1" >0.012657</td>
#       <td id="T_4a796_row1_col2" class="data row1 col2" >0.007229</td>
#       <td id="T_4a796_row1_col3" class="data row1 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a796_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_4a796_row2_col1" class="data row2 col1" >0.011957</td>
#       <td id="T_4a796_row2_col2" class="data row2 col2" >0.007233</td>
#       <td id="T_4a796_row2_col3" class="data row2 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a796_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_4a796_row3_col1" class="data row3 col1" >0.012694</td>
#       <td id="T_4a796_row3_col2" class="data row3 col2" >0.007085</td>
#       <td id="T_4a796_row3_col3" class="data row3 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a796_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_4a796_row4_col1" class="data row4 col1" >0.016197</td>
#       <td id="T_4a796_row4_col2" class="data row4 col2" >0.019089</td>
#       <td id="T_4a796_row4_col3" class="data row4 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a796_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_4a796_row5_col1" class="data row5 col1" >0.111453</td>
#       <td id="T_4a796_row5_col2" class="data row5 col2" >0.012659</td>
#       <td id="T_4a796_row5_col3" class="data row5 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a796_row6_col0" class="data row6 col0" >image_full_gray</td>
#       <td id="T_4a796_row6_col1" class="data row6 col1" >0.111863</td>
#       <td id="T_4a796_row6_col2" class="data row6 col2" >0.012406</td>
#       <td id="T_4a796_row6_col3" class="data row6 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a796_row7_col0" class="data row7 col0" >limiarização_binária </td>
#       <td id="T_4a796_row7_col1" class="data row7 col1" >0.109337</td>
#       <td id="T_4a796_row7_col2" class="data row7 col2" >0.007384</td>
#       <td id="T_4a796_row7_col3" class="data row7 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a796_row8_col0" class="data row8 col0" >limiarização_de_otsu</td>
#       <td id="T_4a796_row8_col1" class="data row8 col1" >0.109902</td>
#       <td id="T_4a796_row8_col2" class="data row8 col2" >0.007372</td>
#       <td id="T_4a796_row8_col3" class="data row8 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a796_row9_col0" class="data row9 col0" >original</td>
#       <td id="T_4a796_row9_col1" class="data row9 col1" >0.114535</td>
#       <td id="T_4a796_row9_col2" class="data row9 col2" >0.022482</td>
#       <td id="T_4a796_row9_col3" class="data row9 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4a796_row10_col0" class="data row10 col0" >bilateral</td>
#       <td id="T_4a796_row10_col1" class="data row10 col1" >0.039923</td>
#       <td id="T_4a796_row10_col2" class="data row10 col2" >0.018060</td>
#       <td id="T_4a796_row10_col3" class="data row10 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4a796_row11_col0" class="data row11 col0" >image_full_gray</td>
#       <td id="T_4a796_row11_col1" class="data row11 col1" >0.026173</td>
#       <td id="T_4a796_row11_col2" class="data row11 col2" >0.011682</td>
#       <td id="T_4a796_row11_col3" class="data row11 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_4a796_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4a796_row12_col0" class="data row12 col0" >limiarização_binária</td>
#       <td id="T_4a796_row12_col1" class="data row12 col1" >0.024522</td>
#       <td id="T_4a796_row12_col2" class="data row12 col2" >0.011376</td>
#       <td id="T_4a796_row12_col3" class=

# %% [markdown]
# ## Texts in lowercase

# %%
exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

# Com textos processados em lowercase
result_filtered_IIIT5K = get_IIIT5K_dataset()

result_filtered_IIIT5K = get_process_dataset_lowercase(result_filtered_IIIT5K, 'words')

result_filtered_IIIT5K = get_metrics_lowercase(result_filtered_IIIT5K, '_lowercase', 'words')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_IIIT5K, exp_list, fluxo_list, '_lowercase')

result_IIIT5K_lowercase = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_IIIT5K_lowercase.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_ba693_row0_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ba693_row0_col2, #T_ba693_row3_col5, #T_ba693_row4_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T
{
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_ba693_row15_col5 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_ba693_row15_col6, #T_ba693_row15_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_ba693_row15_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ba693_row16_col2, #T_ba693_row18_col2, #T_ba693_row19_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_ba693_row16_col4, #T_ba693_row18_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_ba693_row16_col5, #T_ba693_row18_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ba693_row16_col6, #T_ba693_row16_col8, #T_ba693_row18_col6, #T_ba693_row18_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_ba693_row17_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_ba693_row17_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ba693_row17_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_ba693_row17_col5 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_ba693_row17_col6, #T_ba693_row17_col8 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ba693_row17_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ba693_row19_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_ba693_row19_col6, #T_ba693_row19_col8 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_ba693_row19_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# </style>
# <table id="T_ba693" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba693_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_ba693_level0_col1" class="col_heading level0 col1" >wer_lowercase_mean</th>
#       <th id

# %% [markdown]
# ## Texts in lowercase and removed special characters and punctuations

# %%
exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

# Com textos processados em lowercase
result_filtered_IIIT5K = get_IIIT5K_dataset()

result_filtered_IIIT5K = get_process_dataset_lowercase(result_filtered_IIIT5K, 'words')
result_filtered_IIIT5K = get_process_dataset_without_symbols(result_filtered_IIIT5K, 'words')
result_filtered_IIIT5K['words'] = result_filtered_IIIT5K['words'].apply(lambda x: None if x.isspace() else x)
result_filtered_IIIT5K.dropna(subset=['words'], inplace=True)

result_filtered_IIIT5K = get_metrics_lowercase(result_filtered_IIIT5K, '_no_schar', 'words')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_IIIT5K, exp_list, fluxo_list, '_no_schar')

result_IIIT5K_lowercase_no_special = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_IIIT5K_lowercase_no_special.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_d5256_row0_col1, #T_d5256_row16_col7, #T_d5256_row18_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_d5256_row0_col2, #T_d5256_row3_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_d5256_row0_col3, #T_d5256_row12_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d5256_row0_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_d5256_row0_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_d5256_row0_col6, #T_d5256_row0_col8, #T_d5256_row10_col7, #T_d5256_row14_col7 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_d5256_row0_col7 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_d5256_row1_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d5256_row1_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_d5256_row1_col3, #T_d5256_row4_col3, #T_d5256_row13_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d5256_row1_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d5256_row1_col5, #T_d5256_row4_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d5256_row1_col6, #T_d5256_row1_col8 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_d5256_row1_col7, #T_d5256_row4_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_d5256_row2_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d5256_row2_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_d5256_row2_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_d5256_row2_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_d5256_row2_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_d5256_row2_col6, #T_d5256_row2_col8, #T_d5256_row7_col1, #T_d5256_row7_col3, #T_d5256_row7_col5, #T_d5256_row11_col7, #T_d5256_row19_col2, #T_d5256_row19_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d5256_row2_col7, #T_d5256_row8_col6, #T_d5256_row8_col8 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_d5256_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T
class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5256_level0_col0"

# %% [markdown]
# # SVHN

# %%
result_filtered_svhn = get_svhn_dataset()
result_filtered_svhn
# Out:
#         label                 filter prediction  cv2 time  prediction time  \
# 0          31               original        NaN  0.000000         0.008890
# 1          31        image_full_gray        NaN  0.000014         0.005503
# 2          31   limiarização_de_otsu        NaN  0.000012         0.005413
# 3          31   limiarização_binária        NaN  0.000003         0.005227
# 4          31              bilateral        NaN  0.000283         0.005213
# ...       ...                    ...        ...       ...              ...
# 261355    183               original         \v  0.000000         0.147386
# 261356    183        image_full_gray         vo  0.000178         0.121544
# 261357    183   limiarização_de_otsu         vo  0.000185         0.120769
# 261358    183  limiarização_binária          b2  0.000026         0.113375
# 261359    183              bilateral         bo  0.011192         0.122787
#
#         wer  cer  wil  wip  mer                             fluxo  time_total
# 0       1.0  1.0  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR    0.008890
# 1       1.0  1.0  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR    0.005517
# 2       1.0  1.0  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR    0.005426
# 3       1.0  1.0  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR    0.005230
# 4       1.0  1.0  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR    0.005497
# ...     ...  ...  ...  ...  ...                               ...         ...
# 261355  1.0  1.0  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract    0.147386
# 261356  1.0  1.0  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract    0.121722
# 261357  1.0  1.0  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract    0.120954
# 261358  1.0  1.0  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract    0.113401
# 261359  1.0  1.0  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract    0.133978
#
# [261360 rows x 12 columns]

# %% [markdown]
# ## Default - No Processing

# %%
result_filtered_svhn = get_svhn_dataset()

exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_svhn, exp_list, fluxo_list)

opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total  = get_groupby_timeout(result_filtered_svhn, exp_list, fluxo_list)

result_SVHN = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)
result_SVHN_time_total = pd.concat([opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total], ignore_index=True)

display(result_SVHN.style.background_gradient(cmap='coolwarm'))
display(result_SVHN_time_total.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_3c603_row0_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_3c603_row0_col2, #T_3c603_row0_col4, #T_3c603_row5_col6, #T_3c603_row5_col7, #T_3c603_row5_col8, #T_3c603_row10_col3, #T_3c603_row11_col1, #T_3c603_row11_col3, #T_3c603_row11_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_
{
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_3c603_row16_col6, #T_3c603_row16_col8, #T_3c603_row18_col6, #T_3c603_row18_col8, #T_3c603_row19_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_3c603_row16_col7, #T_3c603_row18_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_3c603_row17_col1, #T_3c603_row17_col5, #T_3c603_row19_col2 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_3c603_row17_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_3c603_row17_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_3c603_row17_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3c603_row17_col6, #T_3c603_row17_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_3c603_row17_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_3c603_row19_col1 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_3c603_row19_col6, #T_3c603_row19_col8 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# </style>
# <table id="T_3c603" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c603_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_3c603_level0_col1" class="col_heading level0 col1" >wer_mean</th>
#       <th id="T_3c603_level0_col2" class="col_heading level0 col2" >wer_std</th>
#       <th id="T_3c603_level0_col3" class="col_heading level0 col3" >cer_mean</th>
#       <th
# <style type="text/css">
# #T_1b699_row0_col1, #T_1b699_row1_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1b699_row0_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1b699_row1_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1b699_row2_col1, #T_1b699_row3_col1, #T_1b699_row17_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1b699_row2_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1b699_row3_col2, #T_1b699_row4_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1b699_row4_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1b699_row5_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_1b699_row5_col2, #T_1b699_row15_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1b699_row6_col1 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_1b699_row6_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1b699_row7_col1, #T_1b699_row8_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_1b699_row7_col2, #T_1b699_row11_col2, #T_1b699_row12_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1b699_row8_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_1b699_row9_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_1b699_row9_col2, #T_1b699_row19_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1b699_row10_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_1b699_row10_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_1b699_row11_col1, #T_1b699_row14_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1b699_row12_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_1b699_row13_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1b699_row13_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1b699_row14_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1b699_row15_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_1b699_row16_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_1b699_row16_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_1b699_row17_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_1b699_row18_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_1b699_row18_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1b699_row19_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b699" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b699_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_1b699_level0_col1" class="col_heading level0 col1" >time_total_mean</th>
#       <th id="T_1b699_level0_col2" class="col_heading level0 col2" >time_total_std</th>
#       <th id="T_1b699_level0_col3" class="col_heading level0 col3" >fluxo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b699_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b699_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_1b699_row0_col1" class="data row0 col1" >0.009659</td>
#       <td id="T_1b699_row0_col2" class="data row0 col2" >0.007067</td>
#       <td id="T_1b699_row0_col3" class="data row0 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b699_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_1b699_row1_col1" class="data row1 col1" >0.009597</td>
#       <td id="T_1b699_row1_col2" class="data row1 col2" >0.005471</td>
#       <td id="T_1b699_row1_col3" class="data row1 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b699_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_1b699_row2_col1" class="data row2 col1" >0.008102</td>
#       <td id="T_1b699_row2_col2" class="data row2 col2" >0.004704</td>
#       <td id="T_1b699_row2_col3" class="data row2 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b699_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_1b699_row3_col1" class="data row3 col1" >0.008637</td>
#       <td id="T_1b699_row3_col2" class="data row3 col2" >0.005796</td>
#       <td id="T_1b699_row3_col3" class="data row3 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b699_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_1b699_row4_col1" class="data row4 col1" >0.010263</td>
#       <td id="T_1b699_row4_col2" class="data row4 col2" >0.005786</td>
#       <td id="T_1b699_row4_col3" class="data row4 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b699_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_1b699_row5_col1" class="data row5 col1" >0.110595</td>
#       <td id="T_1b699_row5_col2" class="data row5 col2" >0.010555</td>
#       <td id="T_1b699_row5_col3" class="data row5 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b699_row6_col0" class="data row6 col0" >image_full_gray</td>
#       <td id="T_1b699_row6_col1" class="data row6 col1" >0.111083</td>
#       <td id="T_1b699_row6_col2" class="data row6 col2" >0.009769</td>
#       <td id="T_1b699_row6_col3" class="data row6 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b699_row7_col0" class="data row7 col0" >limiarização_binária </td>
#       <td id="T_1b699_row7_col1" class="data row7 col1" >0.107433</td>
#       <td id="T_1b699_row7_col2" class="data row7 col2" >0.005644</td>
#       <td id="T_1b699_row7_col3" class="data row7 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b699_row8_col0" class="data row8 col0" >limiarização_de_otsu</td>
#       <td id="T_1b699_row8_col1" class="data row8 col1" >0.107916</td>
#       <td id="T_1b699_row8_col2" class="data row8 col2" >0.005288</td>
#       <td id="T_1b699_row8_col3" class="data row8 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b699_row9_col0" class="data row9 col0" >original</td>
#       <td id="T_1b699_row9_col1" class="data row9 col1" >0.117117</td>
#       <td id="T_1b699_row9_col2" class="data row9 col2" >0.021262</td>
#       <td id="T_1b699_row9_col3" class="data row9 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1b699_row10_col0" class="data row10 col0" >bilateral</td>
#       <td id="T_1b699_row10_col1" class="data row10 col1" >0.033676</td>
#       <td id="T_1b699_row10_col2" class="data row10 col2" >0.007650</td>
#       <td id="T_1b699_row10_col3" class="data row10 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1b699_row11_col0" class="data row11 col0" >image_full_gray</td>
#       <td id="T_1b699_row11_col1" class="data row11 col1" >0.020820</td>
#       <td id="T_1b699_row11_col2" class="data row11 col2" >0.005667</td>
#       <td id="T_1b699_row11_col3" class="data row11 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_1b699_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1b699_row12_col0" class="data row12 col0" >limiarização_binária</td>
#       <td id="T_1b699_row12_col1" class="data row12 col1" >0.018111</td>
#       <td id=

# %% [markdown]
# Para a base SVHN podemos observar:
# -  O fluxo [ESRGAN -> OpenCV -> EASYOCR] para os filtros bilateral, image_full_gray e original tiveram resultados parecidos.

# %% [markdown]
# `>> a base SVHN é de apenas números, logo não faz necessário fazer o lowercase e o processamento dos caracteres`

# %% [markdown]
# # SROEI

# %%
result_filtered_SROEI = get_SROEI_dataset()
result_filtered_SROEI
# Out:
#                                  label                 filter  \
# 0                           ROUNDING :               original
# 1                           ROUNDING :        image_full_gray
# 2                           ROUNDING :   limiarização_de_otsu
# 3                           ROUNDING :   limiarização_binária
# 4                           ROUNDING :              bilateral
# ...                                ...                    ...
# 374075  TAMPOI,81200 JOHOR BAHRU,JOHOR               original
# 374076  TAMPOI,81200 JOHOR BAHRU,JOHOR        image_full_gray
# 374077  TAMPOI,81200 JOHOR BAHRU,JOHOR   limiarização_de_otsu
# 374078  TAMPOI,81200 JOHOR BAHRU,JOHOR  limiarização_binária
# 374079  TAMPOI,81200 JOHOR BAHRU,JOHOR              bilateral
#
#                                prediction  cv2 time  prediction time  \
# 0                                Rounding  0.000000         0.690343
# 1                                Rounding  0.000064         0.014858
# 2                                Rounding  0.000062         0.013562
# 3                                Rounding  0.000005         0.013031
# 4                                Rounding  0.001008         0.014480
# ...                                   ...       ...              ...
# 374075   Tampot,8t 200 Johor Bahru, Johor  0.000000         0.413532
# 374076   Tampot,8t 200 Johor Bahru, Johor  0.000231         0.258180
# 374077   Tampot,8t 200 Johor Bahru, Johor  0.000910         0.261692
# 374078  Tampot,81t 200 Johor Bahru, Johor  0.000044         0.214300
# 374079   Tampot,8t 200 Johor Bahru, Johor  0.066221         0.246524
#
#              wer       cer  wil  wip  mer                             fluxo  \
# 0       1.000000  0.900000  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR
# 1       1.000000  0.900000  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR
# 2       1.000000  0.900000  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR
# 3       1.000000  0.900000  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR
# 4       1.000000  0.900000  1.0  0.0  1.0  OpenCV[todos preproc] -> EASYOCR
# ...          ...       ...  ...  ...  ...                               ...
# 374075  1.666667  0.666667  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract
# 374076  1.666667  0.666667  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract
# 374077  1.666667  0.666667  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract
# 374078  1.666667  0.666667  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract
# 374079  1.666667  0.666667  1.0  0.0  1.0     ESRGAN -> OpenCV -> Tesseract
#
#         time_total
# 0         0.690343
# 1         0.014922
# 2         0.013624
# 3         0.013036
# 4         0.015488
# ...            ...
# 374075    0.413532
# 374076    0.258411
# 374077    0.262601
# 374078    0.214344
# 374079    0.312745
#
# [374080 rows x 12 columns]

# %% [markdown]
# ## default - No Processing

# %%
result_filtered_SROEI = get_SROEI_dataset()

exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_SROEI, exp_list, fluxo_list)

opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total  = get_groupby_timeout(result_filtered_SROEI, exp_list, fluxo_list)

result_SROEI = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)
result_SROEI_time_total = pd.concat([opencv_easyocr_time_total, opencv_tesseract_time_total, ersgan_opencv_easyocr_time_total, ersgan_opencv_tesseract_time_total], ignore_index=True)

display(result_SROEI.style.background_gradient(cmap='coolwarm'))
display(result_SROEI_time_total.style.background_gradient(cmap='coolwarm'))
# Out:
# <style type="text/css">
# #T_aa1bf_row0_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T
col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_aa1bf_row11_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_aa1bf_row11_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_aa1bf_row11_col7 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_aa1bf_row12_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_aa1bf_row12_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_aa1bf_row12_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_aa1bf_row12_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_aa1bf_row12_col6, #T_aa1bf_row12_col8 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_aa1bf_row12_col7, #T_aa1bf_row16_col4, #T_aa1bf_row18_col4 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_aa1bf_row13_col3, #T_aa1bf_row17_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col6, #T_aa1bf_row13_col8, #T_aa1bf_row14_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_aa1bf_row13_col7 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_aa1bf_row14_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_aa1bf_row15_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_aa1bf_row15_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_aa1bf_row15_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_aa1bf_row15_col6, #T_aa1bf_row15_col8, #T_aa1bf_row19_col6, #T_aa1bf_row19_col8 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_aa1bf_row15_col7, #T_aa1bf_row19_col7 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_aa1bf_row16_col1, #T_aa1bf_row18_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_aa1bf_row16_col2, #T_aa1bf_row18_col2 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_aa1bf_row16_col3, #T_aa1bf_row18_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_aa1bf_row16_col5, #T_aa1bf_row18_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_aa1bf_row16_col6, #T_aa1bf_row16_col8, #T_aa1bf_row18_col6, #T_aa1bf_row18_col8 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_aa1bf_row17_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_aa1bf_row17_col6, #T_aa1bf_row17_col8, #T_aa1bf_row19_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_aa1bf_row17_col7 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_aa1bf_row19_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_aa1bf_row19_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_aa1bf_row19_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aa1bf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa1bf_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_aa1bf_level0_col1" class="col_heading level0 col1" >wer_mean</th>
#       <th id="T_aa1bf_level0_col2" class="col_heading level0 col2" >wer_
# <style type="text/css">
# #T_8a7e9_row0_col1, #T_8a7e9_row1_col1, #T_8a7e9_row2_col1, #T_8a7e9_row3_col1, #T_8a7e9_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8a7e9_row0_col2, #T_8a7e9_row2_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_8a7e9_row1_col2, #T_8a7e9_row4_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_8a7e9_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_8a7e9_row5_col1, #T_8a7e9_row8_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8a7e9_row5_col2, #T_8a7e9_row8_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_8a7e9_row6_col1, #T_8a7e9_row16_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_8a7e9_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8a7e9_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_8a7e9_row7_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_8a7e9_row9_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_8a7e9_row9_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_8a7e9_row10_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_8a7e9_row10_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8a7e9_row11_col1, #T_8a7e9_row13_col1, #T_8a7e9_row14_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_8a7e9_row11_col2, #T_8a7e9_row13_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_8a7e9_row12_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8a7e9_row12_col2, #T_8a7e9_row14_col2 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_8a7e9_row15_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_8a7e9_row15_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_8a7e9_row16_col1, #T_8a7e9_row18_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_8a7e9_row17_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_8a7e9_row17_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_8a7e9_row18_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8a7e9_row19_col1, #T_8a7e9_row19_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8a7e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a7e9_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_8a7e9_level0_col1" class="col_heading level0 col1" >time_total_mean</th>
#       <th id="T_8a7e9_level0_col2" class="col_heading level0 col2" >time_total_std</th>
#       <th id="T_8a7e9_level0_col3" class="col_heading level0 col3" >fluxo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a7e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a7e9_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_8a7e9_row0_col1" class="data row0 col1" >0.016262</td>
#       <td id="T_8a7e9_row0_col2" class="data row0 col2" >0.008800</td>
#       <td id="T_8a7e9_row0_col3" class="data row0 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a7e9_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_8a7e9_row1_col1" class="data row1 col1" >0.015442</td>
#       <td id="T_8a7e9_row1_col2" class="data row1 col2" >0.007245</td>
#       <td id="T_8a7e9_row1_col3" class="data row1 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a7e9_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_8a7e9_row2_col1" class="data row2 col1" >0.016182</td>
#       <td id="T_8a7e9_row2_col2" class="data row2 col2" >0.008608</td>
#       <td id="T_8a7e9_row2_col3" class="data row2 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a7e9_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_8a7e9_row3_col1" class="data row3 col1" >0.015834</td>
#       <td id="T_8a7e9_row3_col2" class="data row3 col2" >0.006774</td>
#       <td id="T_8a7e9_row3_col3" class="data row3 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a7e9_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_8a7e9_row4_col1" class="data row4 col1" >0.016790</td>
#       <td id="T_8a7e9_row4_col2" class="data row4 col2" >0.012067</td>
#       <td id="T_8a7e9_row4_col3" class="data row4 col3" >OpenCV[todos preproc] -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a7e9_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_8a7e9_row5_col1" class="data row5 col1" >0.114665</td>
#       <td id="T_8a7e9_row5_col2" class="data row5 col2" >0.015680</td>
#       <td id="T_8a7e9_row5_col3" class="data row5 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a7e9_row6_col0" class="data row6 col0" >image_full_gray</td>
#       <td id="T_8a7e9_row6_col1" class="data row6 col1" >0.113934</td>
#       <td id="T_8a7e9_row6_col2" class="data row6 col2" >0.014239</td>
#       <td id="T_8a7e9_row6_col3" class="data row6 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8a7e9_row7_col0" class="data row7 col0" >limiarização_binária </td>
#       <td id="T_8a7e9_row7_col1" class="data row7 col1" >0.112982</td>
#       <td id="T_8a7e9_row7_col2" class="data row7 col2" >0.013750</td>
#       <td id="T_8a7e9_row7_col3" class="data row7 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8a7e9_row8_col0" class="data row8 col0" >limiarização_de_otsu</td>
#       <td id="T_8a7e9_row8_col1" class="data row8 col1" >0.114693</td>
#       <td id="T_8a7e9_row8_col2" class="data row8 col2" >0.015732</td>
#       <td id="T_8a7e9_row8_col3" class="data row8 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8a7e9_row9_col0" class="data row9 col0" >original</td>
#       <td id="T_8a7e9_row9_col1" class="data row9 col1" >0.116553</td>
#       <td id="T_8a7e9_row9_col2" class="data row9 col2" >0.017491</td>
#       <td id="T_8a7e9_row9_col3" class="data row9 col3" >OpenCV[todos preproc] -> Tesseract</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8a7e9_row10_col0" class="data row10 col0" >bilateral</td>
#       <td id="T_8a7e9_row10_col1" class="data row10 col1" >0.074185</td>
#       <td id="T_8a7e9_row10_col2" class="data row10 col2" >0.046164</td>
#       <td id="T_8a7e9_row10_col3" class="data row10 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8a7e9_row11_col0" class="data row11 col0" >image_full_gray</td>
#       <td id="T_8a7e9_row11_col1" class="data row11 col1" >0.047685</td>
#       <td id="T_8a7e9_row11_col2" class="data row11 col2" >0.028398</td>
#       <td id="T_8a7e9_row11_col3" class="data row11 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8a7e9_row12_col0" class="data row12 col0" >limiarização_binária</td>
#       <td id="T_8a7e9_row12_col1" class="data row12 col1" >0.046734</td>
#       <td id="T_8a7e9_row12_col2" class="data row12 col2" >0.028082</td>
#       <td id="T_8a7e9_row12_col3" class="data row12 col3" >ESRGAN -> OpenCV -> EASYOCR</td>
#     </tr>
#     <tr>
#       <th id="T_8a7e9_level0_row13" class="row_heading level0 row13" >13</th>

# %% [markdown]
# Para a base SROEI podemos observar:
# -  O fluxo [ESRGAN -> OpenCV -> EASYOCR] para os filtros bilateral, image_full_gray e original tiveram resultados parecidos.

# %% [markdown]
# ## Texts in lowercase

# %%
result_filtered_SROEI = get_SROEI_dataset()

exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

result_filtered_SROEI = get_process_dataset_lowercase(result_filtered_SROEI, 'label')

result_filtered_SROEI = get_metrics_lowercase(result_filtered_SROEI, '_lowercase', 'label')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_SROEI, exp_list, fluxo_list, '_lowercase')

result_filtered_SROEI_lowercase = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_filtered_SROEI_lowercase.style.background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_e11b7_row0_col1 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col2 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col3, #T_e11b7_row8_col2 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col4, #T_e11b7_row11_col2, #T_e11b7_row12_col2, #T_e11b7_row14_col2 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col5 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col6, #T_e11b7_row0_col8 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_e11b7_row0_col7 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_e11b7_row1_col1, #T_e11b7_row1_col5, #T_e11b7_row3_col3, #T_e11b7_row3_col4, #T_e11b7_row4_col1, #T_e11b7_row4_col5, #T_e11b7_row6_col2, #T_e11b7_row8_col6, #T_e11b7_row8_col7, #T_e11b7_row8_col8, #T_e11b7_row9_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e11b7_row1_col2, #T_e11b7_row2_col3, #T_e11b7_row4_col2 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row1_col3, #T_e11b7_row4_col3 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_e11b7_row1_col4, #T_e11b7_row4_col4, #T_e11b7_row15_col5, #T_e11b7_row19_col5 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_e11b7_row1_col6, #T_e11b7_row1_col8 {
#   background-color: #aadc32;
#   color: #000000;
# }
# #T_e11b7_row1_col7, #T_e11b7_row4_col7, #T_e11b7_row8_col1, #T_e11b7_row8_col3, #T_e11b7_row8_col5, #T_e11b7_row15_col6, #T_e11b7_row15_col8, #T_e11b7_row17_col2, #T_e11b7_row17_col4, #T_e11b7_row19_col6, #T_e11b7_row19_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e11b7_row2_col1 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_e11b7_row2_col2 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_e11b7_row2_col4, #T_e11b7_row10_col2 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_e11b7_row2_col5 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_e11b7_row2_col6, #T_e11b7_row2_col8 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_e11b7_row2_col7 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_e11b7_row3_col1, #T_e11b7_row10_col4, #T_e11b7_row10_col5, #T_e11b7_row11_col5, #T_e11b7_row14_col5 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_e11b7_row3_col2 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_e11b7_row3_col5 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_e11b7_row3_col6, #T_e11b7_row3_col8 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_e11b7_row3_col7 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_e11b7_row4_col6, #T_e11b7_row4_col8, #T_e11b7_row10_col7, #T_e11b7_row11_col7, #T_e11b7_row14_col7, #T_e11b7_row15_col4 {
#   background-color: #a8db34;
#   color: #000000;
# }
# #T_e11b7_row5_col1, #T_e11b7_row9_col4 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_e11b7_row5_col2 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_e11b7_row5_col3, #T_e11b7_row11_col6, #T_e11b7_row11_col8, #T_e11b7_row14_col6, #T_e11b7_row14_col8 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_e11b7_row5_col4 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_e11b7_row5_col5 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_e11b7_row5_col6, #T_e11b7_row5_col8 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_e11b7_row5_col7 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row6_col1, #T_e11b7_row9_col1 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row6_col3, #T_e11b7_row9_col3 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_e11b7_row6_col4 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_e11b7_row6_col5, #T_e11b7_row9_col5 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_e11b7_row6_col6, #T_e11b7_row6_col8, #T_e11b7_row9_col6, #T_e11b7_row9_col8 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_e11b7_row6_col7, #T_e11b7_row9_col7 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_e11b7_row7_col1 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_e11b7_row7_col2 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_e11b7_row7_col3 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_e11b7_row7_col4 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row7_col5 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_e11b7_row7_col6, #T_e11b7_row7_col8 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_e11b7_row7_col7 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_e11b7_row8_col4 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row10_col1, #T_e11b7_row11_col1, #T_e11b7_row14_col1 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_e11b7_row10_col3, #T_e11b7_row14_col3 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_e11b7_row10_col6, #T_e11b7_row10_col8, #T_e11b7_row13_col6, #T_e11b7_row13_col8 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_e11b7_row11_col3, #T_e11b7_row19_col3 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_e11b7_row11_col4, #T_e11b7_row14_col4 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_e11b7_row12_col1 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_e11b7_row12_col3, #T_e11b7_row13_col2, #T_e11b7_row13_col3 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_e11b7_row12_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_e11b7_row12_col5 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_e11b7_row12_col6, #T_e11b7_row12_col8 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_e11b7_row12_col7 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_e11b7_row13_col1 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_e11b7_row13_col4 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_e11b7_row13_col5 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_e11b7_row13_col7 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_e11b7_row15_col1 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_e11b7_row15_col2, #T_e11b7_row16_col7, #T_e11b7_row18_col7 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_e11b7_row15_col3 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_e11b7_row15_col7, #T_e11b7_row19_col7 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_e11b7_row16_col1, #T_e11b7_row18_col1 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_e11b7_row16_col2, #T_e11b7_row18_col2 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_e11b7_row16_col3, #T_e11b7_row18_col3 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_e11b7_row16_col4, #T_e11b7_row18_col4 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_e11b7_row16_col5, #T_e11b7_row18_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_e11b7_row16_col6, #T_e11b7_row16_col8, #T_e11b7_row18_col6, #T_e11b7_row18_col8 {
#   background-color: #fbe723;
#   color: #000000;
# }
# #T_e11b7_row17_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_e11b7_row17_col3 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_e11b7_row17_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_e11b7_row17_col6, #T_e11b7_row17_col8 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_e11b7_row17_col7 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_e11b7_row19_col1 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_e11b7_row19_col2 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_e11b7_row19_col4 {
#   background-color: #a2da37;
#   color: #000000;
# }
# </style>
# <table id="T_e11b7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e11b7_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_e11b7_level0_col1" class="col_heading level0 col1" >wer_lowercase_mean</th>
#       <th id="T_e11b7_level0_col2" class="col_heading level0 col2" >wer_lowercase_std</th>
#       <th id="T_e11b7_level0_col3" class="col_heading level0 col3" >cer_lowercase_mean</th>
#       <th id="T_e11b7_level0_col4" class="col_heading level0 col4" >cer_lowercase_std</th>
#       <th id="T_e11b7_level0_col5" class="col_heading level0 col5" >wil_lowercase_mean</th>
#       <th id="T_e11b7_level0_col6" class="col_heading level0 col6" >wil_lowercase_std</th>

# %% [markdown]
# ## Texts in lowercase and removed special characters and punctuations

# %%
result_filtered_SROEI = get_SROEI_dataset()

exp_list = ['OpenCV[todos preproc] -> EASYOCR',
            'OpenCV[todos preproc] -> Tesseract',
            'ESRGAN -> OpenCV -> EASYOCR',
            'ESRGAN -> OpenCV -> Tesseract']

fluxo_list = ['OpenCV[todos preproc] -> EASYOCR',
              'OpenCV[todos preproc] -> Tesseract',
              'ESRGAN -> OpenCV -> EASYOCR',
              'ESRGAN -> OpenCV -> Tesseract']

result_filtered_SROEI = get_process_dataset_lowercase(result_filtered_SROEI, 'label')
result_filtered_SROEI = get_process_dataset_without_symbols(result_filtered_SROEI, 'label')
result_filtered_SROEI['label'] = result_filtered_SROEI['label'].apply(lambda x: None if x.isspace() else x)
result_filtered_SROEI['label'] = result_filtered_SROEI['label'].replace(r'^\s*$', pd.NA, regex=True)
result_filtered_SROEI = result_filtered_SROEI.dropna(subset=['label'])

result_filtered_SROEI = get_metrics_lowercase(result_filtered_SROEI, '_no_schar', 'label')

opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result = get_groupby_results(result_filtered_SROEI, exp_list, fluxo_list, '_no_schar')

result_filtered_SROEI_lowercase_no_special = pd.concat([opencv_easyocr_result_df, opencv_tesseract_result, ersgan_opencv_easyocr_result, ersgan_opencv_tesseract_result], ignore_index=True)

# results
display(result_filtered_SROEI_lowercase_no_special.style.background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_f80ca_row0_col1, #T_f80ca_row2_col1 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_f80ca_row0_col2 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_f80ca_row0_col3 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_f80ca_row0_col4, #T_f80ca_row2_col4, #T_f80ca_row19_col5 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_f80ca_row0_col5 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_f80ca_row0_col6, #T_f80ca_row0_col8 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_f80ca_row0_col7 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_f80ca_row1_col1, #T_f80ca_row1_col5, #T_f80ca_row3_col3, #T_f80ca_row3_col4, #T_f80ca_row4_col1, #T_f80ca_row4_col5, #T_f80ca_row6_col2, #T_f80ca_row8_col6, #T_f80ca_row8_col7, #T_f80ca_row8_col8, #T_f80ca_row9_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f80ca_row1_col2 {
#   background-color: #3b518b;
#   color: #f1f1f1;
# }
# #T_f80ca_row1_col3, #T_f80ca_row4_col3 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_f80ca_row1_col4, #T_f80ca_row4_col4 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_f80ca_row1_col6, #T_f80ca_row1_col8, #T_f80ca_row4_col6, #T_f80ca_row4_col8 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_f80ca_row1_col7, #T_f80ca_row4_col7, #T_f80ca_row8_col1, #T_f80ca_row8_col3, #T_f80ca_row8_col5, #T_f80ca_row15_col6, #T_f80ca_row15_col8, #T_f80ca_row16_col6, #T_f80ca_row16_col8, #T_f80ca_row17_col2, #T_f80ca_row17_col4, #T_f80ca_row18_col6, #T_f80ca_row18_col8, #T_f80ca_row19_col6, #T_f80ca_row19_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f80ca_row2_col2 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_f80ca_row2_col3 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_f80ca_row2_col5, #T_f80ca_row17_col1 {
#   background-color: #2c718e;
#   color: #f1f1f1;
# }
# #T_f80ca_row2_col6, #T_f80ca_row2_col8 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_f80ca_row2_col7 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_f80ca_row3_col1 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_f80ca_row3_col2 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_f80ca_row3_col5 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_f80ca_row3_col6, #T_f80ca_row3_col8, #T_f80ca_row10_col7, #T_f80ca_row14_col7 {
#   background-color: #a8db34;
#   color: #000000;
# }
# #T_f80ca_row3_col7 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_f80ca_row4_col2, #T_f80ca_row17_col5 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_f80ca_row5_col1, #T_f80ca_row6_col4 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_f80ca_row5_col2 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_f80ca_row5_col3 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_f80ca_row5_col4 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_f80ca_row5_col5, #T_f80ca_row6_col3, #T_f80ca_row14_col6, #T_f80ca_row14_col8 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_f80ca_row5_col6, #T_f80ca_row5_col8 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_f80ca_row5_col7 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_f80ca_row6_col1, #T_f80ca_row9_col1 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_f80ca_row6_col5, #T_f80ca_row9_col5 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_f80ca_row6_col6, #T_f80ca_row6_col8 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_f80ca_row6_col7, #T_f80ca_row9_col7 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_f80ca_row7_col1 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_f80ca_row7_col2 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_f80ca_row7_col3 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_f80ca_row7_col4 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_f80ca_row7_col5, #T_f80ca_row19_col4 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_f80ca_row7_col6, #T_f80ca_row7_col8 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_f80ca_row7_col7 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_f80ca_row8_col2 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_f80ca_row8_col4 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_f80ca_row9_col3, #T_f80ca_row10_col6, #T_f80ca_row10_col8, #T_f80ca_row11_col6, #T_f80ca_row11_col8, #T_f80ca_row13_col6, #T_f80ca_row13_col8 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_f80ca_row9_col4 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_f80ca_row9_col6, #T_f80ca_row9_col8 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_f80ca_row10_col1, #T_f80ca_row10_col5, #T_f80ca_row14_col5 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_f80ca_row10_col2, #T_f80ca_row11_col2 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_f80ca_row10_col3, #T_f80ca_row13_col1 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_f80ca_row10_col4, #T_f80ca_row11_col4 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_f80ca_row11_col1, #T_f80ca_row11_col5 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_f80ca_row11_col3, #T_f80ca_row13_col2 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_f80ca_row11_col7 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_f80ca_row12_col1, #T_f80ca_row12_col5, #T_f80ca_row14_col2 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_f80ca_row12_col2 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_f80ca_row12_col3 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_f80ca_row12_col4 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_f80ca_row12_col6, #T_f80ca_row12_col8 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_f80ca_row12_col7 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_f80ca_row13_col3 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_f80ca_row13_col4 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_f80ca_row13_col5 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_f80ca_row13_col7 {
#   background-color: #89d548;
#   color: #000000;
# }
# #T_f80ca_row14_col1 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_f80ca_row14_col3 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_f80ca_row14_col4 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_f80ca_row15_col1 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_f80ca_row15_col2 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_f80ca_row15_col3, #T_f80ca_row16_col3, #T_f80ca_row18_col3 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_f80ca_row15_col4 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_f80ca_row15_col5 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_f80ca_row15_col7 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_f80ca_row16_col1, #T_f80ca_row18_col1 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_f80ca_row16_col2, #T_f80ca_row17_col6, #T_f80ca_row17_col8, #T_f80ca_row18_col2 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_f80ca_row16_col4, #T_f80ca_row18_col4 {
#   background-color: #c8e020;
#   color: #000000;
# }
# #T_f80ca_row16_col5, #T_f80ca_row18_col5 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_f80ca_row16_col7, #T_f80ca_row18_col7 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_f80ca_row17_col3 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_f80ca_row17_col7 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_f80ca_row19_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_f80ca_row19_col2 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_f80ca_row19_col3 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_f80ca_row19_col7 {
#   background-color: #6ece58;
#   color: #000000;
# }
# </style>
# <table id="T_f80ca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f80ca_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_f80ca_level0_col1" class="col_heading level0 col1" >wer_no_schar_mean</th>
#       <th id="T_f80ca_level0_col2" class="col_heading level0 col2" >wer_no_schar_std</th>
#       <th id="T_f80ca_level0_col3" class="col_heading level0 col3" >cer_no_schar_mean</th>
#       <th id="T_f80ca_level0_col

# %% [markdown]
# # All Results

# %% [markdown]
# ### - Default

# %%
def style_background_gradient(val):
    if val == 'Identity Card':
        color = 'red'
    elif val == 'IIIT5K':
        color = 'blue'
    elif val == 'SVHN':
        color = 'green'
    elif val == 'SROEI':
        color = 'orange'
    else:
        color = 'white'
    return f'background-color: {color}'

# %%
result_identity_card['type'] = 'Identity Card'
result_IIIT5K['type'] = 'IIIT5K'
result_SVHN['type'] = 'SVHN'
result_SROEI['type'] = 'SROEI'

result_all_default = pd.concat([result_identity_card, result_IIIT5K, result_SVHN, result_SROEI], ignore_index=True)

# %%
result_all_default.to_csv('all_results.csv', index=False)

# %%
# %cp -r /content/all_results.csv /content/drive/MyDrive/'Colab Notebooks'/OCR/Pos/results/

# %%
styled_df  = result_all_default.style.applymap(style_background_gradient, subset=['type'])
styled_df
# Out:
# <style type="text/css">
# #T_31413_row0_col10, #T_31413_row1_col10, #T_31413_row2_col10, #T_31413_row3_col10, #T_31413_row4_col10, #T_31413_row5_col10, #T_31413_row6_col10, #T_31413_row7_col10, #T_31413_row8_col10, #T_31413_row9_col10, #T_31413_row10_col10, #T_31413_row11_col10, #T_31413_row12_col10, #T_31413_row13_col10, #T_31413_row14_col10, #T_31413_row15_col10, #T_31413_row16_col10, #T_31413_row17_col10, #T_31413_row18_col10, #T_31413_row19_col10 {
#   background-color: red;
# }
# #T_31413_row20_col10, #T_31413_row21_col10, #T_31413_row22_col10, #T_31413_row23_col10, #T_31413_row24_col10, #T_31413_row25_col10, #T_31413_row26_col10, #T_31413_row27_col10, #T_31413_row28_col10, #T_31413_row29_col10, #T_31413_row30_col10, #T_31413_row31_col10, #T_31413_row32_col10, #T_31413_row33_col10, #T_31413_row34_col10, #T_31413_row35_col10, #T_31413_row36_col10, #T_31413_row37_col10, #T_31413_row38_col10, #T_31413_row39_col10 {
#   background-color: blue;
# }
# #T_31413_row40_col10, #T_31413_row41_col10, #T_31413_row42_col10, #T_31413_row43_col10, #T_31413_row44_col10, #T_31413_row45_col10, #T_31413_row46_col10, #T_31413_row47_col10, #T_31413_row48_col10, #T_31413_row49_col10, #T_31413_row50_col10, #T_31413_row51_col10, #T_31413_row52_col10, #T_31413_row53_col10, #T_31413_row54_col10, #T_31413_row55_col10, #T_31413_row56_col10, #T_31413_row57_col10, #T_31413_row58_col10, #T_31413_row59_col10 {
#   background-color: green;
# }
# #T_31413_row60_col10, #T_31413_row61_col10, #T_31413_row62_col10, #T_31413_row63_col10, #T_31413_row64_col10, #T_31413_row65_col10, #T_31413_row66_col10, #T_31413_row67_col10, #T_31413_row68_col10, #T_31413_row69_col10, #T_31413_row70_col10, #T_31413_row71_col10, #T_31413_row72_col10, #T_31413_row73_col10, #T_31413_row74_col10, #T_31413_row75_col10, #T_31413_row76_col10, #T_31413_row77_col10, #T_31413_row78_col10, #T_31413_row79_col10 {
#   background-color: orange;
# }
# </style>
# <table id="T_31413" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31413_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_31413_level0_col1" class="col_heading level0 col1" >wer_mean</th>
#       <th id="T_31413_level0_col2" class="col_heading level0 col2" >wer_std</th>
#       <th id="T_31413_level0_col3" class="col_heading level0 col3" >cer_mean</th>
#       <th id="T_31413_level0_col4" class="col_heading level0 col4" >cer_std</th>
#       <th id="T_31413_level0_col5" class="col_heading level0 col5" >wil_mean</th>
#       <th id="T_31413_level0_col6" class="col_heading level0 col6" >wil_std</th>
#       <th id="T_31413_level0_col7" class="col_heading level0 col7" >wip_mean</th>
#       <th id="T_31413_level0_col8" class="col_heading level0 col8" >wip_std</th>
#       <th id="T_31413_level0_col9" class="col_heading level0 col9" >fluxo</th>
#       <th id="T_31413_level0_col10" class="col_heading level0 col10" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31413_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31413_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_31413_row0_col1" class="data row0 col1" >0.756998</td>
#       <td id="T_31413_row0_col2" class="data row0 col2" >0.549599</td>
#       <td id="T_31413_row0_col3" class="data row0 col3" >0.559238</td>
#       <td id="T_31413_row0_col4" class="data row0 col4" >0.445395</td>
#       <td id="T_31413_row0_col5" class="data row0 col5" >0.713520</td>
#       <td id="T_31413_row0_col6" class="data row0 col6" >0.451922</td>
#       <td id="T_31413_row0_col7" class="data row0 col7" >0.286480</td>
#       <td id="T_31413_row0_col8" class="data row0 col8" >0.451922</td>
#       <td id="T_31413_row0_col9" class="data row0 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_31413_row0_col10" class="data row0 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_31413_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31413_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_31413_row1_col1" class="data row1 col1" >0.506849</td>
#       <td id="T_31413_row1_col2" class="data row1 col2" >0.533263</td>
#       <td id="T_31413_row1_col3" class="data row1 col3" >0.296577</td>
#       <td id="T_31413_row1_col4" class="data row1 col4" >0.394953</td>
#       <td id="T_31413_row1_col5" class="data row1 col5" >0.488237</td>
#       <td id="T_31413_row1_col6" class="data row1 col6" >0.499004</td>
#       <td id="T_31413_row1_col7" class="data row1 col7" >0.511763</td>
#       <td id="T_31413_row1_col8" class="data row1 col8" >0.499004</td>
#       <td id="T_31413_row1_col9" class="data row1 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_31413_row1_col10" class="data row1 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_31413_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31413_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_31413_row2_col1" class="data row2 col1" >0.784395</td>
#       <td id="T_31413_row2_col2" class="data row2 col2" >0.505011</td>
#       <td id="T_31413_row2_col3" class="data row2 col3" >0.590780</td>
#       <td id="T_31413_row2_col4" class="data row2 col4" >0.454271</td>
#       <td id="T_31413_row2_col5" class="data row2 col5" >0.749256</td>
#       <td id="T_31413_row2_col6" class="data row2 col6" >0.433227</td>
#       <td id="T_31413_row2_col7" class="data row2 col7" >0.250744</td>
#       <td id="T_31413_row2_col8" class="data row2 col8" >0.433227</td>
#       <td id="T_31413_row2_col9" class="data row2 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_31413_row2_col10" class="data row2 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_31413_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T
{
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_14693_row6_col4, #T_14693_row57_col7 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_14693_row6_col5, #T_14693_row26_col3, #T_14693_row37_col3 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_14693_row6_col7 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_14693_row7_col1, #T_14693_row19_col3, #T_14693_row24_col7, #T_14693_row28_col6, #T_14693_row28_col8 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_14693_row7_col3, #T_14693_row32_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_14693_row7_col4, #T_14693_row8_col7, #T_14693_row25_col7, #T_14693_row49_col2, #T_14693_row57_col4, #T_14693_row62_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_14693_row7_col5 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_14693_row7_col6, #T_14693_row7_col8, #T_14693_row51_col7, #T_14693_row61_col6, #T_14693_row61_col8, #T_14693_row64_col6, #T_14693_row64_col8 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_14693_row7_col7 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_14693_row8_col1, #T_14693_row15_col6, #T_14693_row15_col8, #T_14693_row63_col6, #T_14693_row63_col8 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_14693_row8_col3, #T_14693_row29_col3, #T_14693_row40_col3 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_14693_row8_col5, #T_14693_row25_col5, #T_14693_row56_col3, #T_14693_row58_col3 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_14693_row8_col6, #T_14693_row8_col8, #T_14693_row22_col3, #T_14693_row24_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_14693_row9_col1, #T_14693_row44_col3, #T_14693_row70_col5, #T_14693_row71_col5, #T_14693_row74_col5 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_14693_row9_col3, #T_14693_row37_col6, #T_14693_row37_col8, #T_14693_row72_col5, #T_14693_row79_col1 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_14693_row9_col4, #T_14693_row44_col2, #T_14693_row55_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_14693_row9_col5, #T_14693_row43_col3, #T_14693_row67_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_14693_row9_col7, #T_14693_row44_col4 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_14693_row10_col1, #T_14693_row68_col4 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_

# %% [markdown]
# ## Texts in lowercase

# %%
result_identity_card_lowercase['type'] = 'Identity Card'
result_IIIT5K_lowercase['type'] = 'IIIT5K'
result_filtered_SROEI_lowercase['type'] = 'SROEI'

result_lowercase = pd.concat([result_identity_card_lowercase, result_IIIT5K_lowercase, result_filtered_SROEI_lowercase], ignore_index=True)

# %%
styled_df  = result_lowercase.style.applymap(style_background_gradient, subset=['type'])
styled_df
# Out:
# <style type="text/css">
# #T_b305a_row0_col10, #T_b305a_row1_col10, #T_b305a_row2_col10, #T_b305a_row3_col10, #T_b305a_row4_col10, #T_b305a_row5_col10, #T_b305a_row6_col10, #T_b305a_row7_col10, #T_b305a_row8_col10, #T_b305a_row9_col10, #T_b305a_row10_col10, #T_b305a_row11_col10, #T_b305a_row12_col10, #T_b305a_row13_col10, #T_b305a_row14_col10, #T_b305a_row15_col10, #T_b305a_row16_col10, #T_b305a_row17_col10, #T_b305a_row18_col10, #T_b305a_row19_col10 {
#   background-color: red;
# }
# #T_b305a_row20_col10, #T_b305a_row21_col10, #T_b305a_row22_col10, #T_b305a_row23_col10, #T_b305a_row24_col10, #T_b305a_row25_col10, #T_b305a_row26_col10, #T_b305a_row27_col10, #T_b305a_row28_col10, #T_b305a_row29_col10, #T_b305a_row30_col10, #T_b305a_row31_col10, #T_b305a_row32_col10, #T_b305a_row33_col10, #T_b305a_row34_col10, #T_b305a_row35_col10, #T_b305a_row36_col10, #T_b305a_row37_col10, #T_b305a_row38_col10, #T_b305a_row39_col10 {
#   background-color: blue;
# }
# #T_b305a_row40_col10, #T_b305a_row41_col10, #T_b305a_row42_col10, #T_b305a_row43_col10, #T_b305a_row44_col10, #T_b305a_row45_col10, #T_b305a_row46_col10, #T_b305a_row47_col10, #T_b305a_row48_col10, #T_b305a_row49_col10, #T_b305a_row50_col10, #T_b305a_row51_col10, #T_b305a_row52_col10, #T_b305a_row53_col10, #T_b305a_row54_col10, #T_b305a_row55_col10, #T_b305a_row56_col10, #T_b305a_row57_col10, #T_b305a_row58_col10, #T_b305a_row59_col10 {
#   background-color: orange;
# }
# </style>
# <table id="T_b305a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b305a_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_b305a_level0_col1" class="col_heading level0 col1" >wer_lowercase_mean</th>
#       <th id="T_b305a_level0_col2" class="col_heading level0 col2" >wer_lowercase_std</th>
#       <th id="T_b305a_level0_col3" class="col_heading level0 col3" >cer_lowercase_mean</th>
#       <th id="T_b305a_level0_col4" class="col_heading level0 col4" >cer_lowercase_std</th>
#       <th id="T_b305a_level0_col5" class="col_heading level0 col5" >wil_lowercase_mean</th>
#       <th id="T_b305a_level0_col6" class="col_heading level0 col6" >wil_lowercase_std</th>
#       <th id="T_b305a_level0_col7" class="col_heading level0 col7" >wip_lowercase_mean</th>
#       <th id="T_b305a_level0_col8" class="col_heading level0 col8" >wip_lowercase_std</th>
#       <th id="T_b305a_level0_col9" class="col_heading level0 col9" >fluxo</th>
#       <th id="T_b305a_level0_col10" class="col_heading level0 col10" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b305a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b305a_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_b305a_row0_col1" class="data row0 col1" >0.718117</td>
#       <td id="T_b305a_row0_col2" class="data row0 col2" >0.566228</td>
#       <td id="T_b305a_row0_col3" class="data row0 col3" >0.490908</td>
#       <td id="T_b305a_row0_col4" class="data row0 col4" >0.446716</td>
#       <td id="T_b305a_row0_col5" class="data row0 col5" >0.674613</td>
#       <td id="T_b305a_row0_col6" class="data row0 col6" >0.468341</td>
#       <td id="T_b305a_row0_col7" class="data row0 col7" >0.325387</td>
#       <td id="T_b305a_row0_col8" class="data row0 col8" >0.468341</td>
#       <td id="T_b305a_row0_col9" class="data row0 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_b305a_row0_col10" class="data row0 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_b305a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b305a_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_b305a_row1_col1" class="data row1 col1" >0.455304</td>
#       <td id="T_b305a_row1_col2" class="data row1 col2" >0.531449</td>
#       <td id="T_b305a_row1_col3" class="data row1 col3" >0.227296</td>
#       <td id="T_b305a_row1_col4" class="data row1 col4" >0.346151</td>
#       <td id="T_b305a_row1_col5" class="data row1 col5" >0.436681</td>
#       <td id="T_b305a_row1_col6" class="data row1 col6" >0.495107</td>
#       <td id="T_b305a_row1_col7" class="data row1 col7" >0.563319</td>
#       <td id="T_b305a_row1_col8" class="data row1 col8" >0.495107</td>
#       <td id="T_b305a_row1_col9" class="data row1 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_b305a_row1_col10" class="data row1 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_b305a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b305a_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_b305a_row2_col1" class="data row2 col1" >0.760429</td>
#       <td id="T_b305a_row2_col2" class="data row2 col2" >0.517835</td>
#       <td id="T_b305a_row2_col3" class="data row2 col3" >0.548457</td>
#       <td id="T_b305a_row2_col4" class="data row2 col4" >0.449113</td>
#       <td id="T_b305a_row2_col5" class="data row2 col5" >0.725268</td>
#       <td id="T_b305a_row2_col6" class="data row2 col6" >0.446178</td>
#       <td id="T_b305a_row2_col7" class="data row2 col7" >0.274732</td>
#       <td id="T_b305a_row2_col8" class="data row2 col8" >0.446178</td>
#       <td id="T_b305a_row2_col9" class="data row2 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_b305a_row2_col10" class="data row2 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_b305a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b305a_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_b305a_row3_col1" class="data row3 col1" >0.810191</td>
#       <td id="T_b305a_row3_col2" class="data row3 col2" >0.485813</td>
#       <td id="T_b305a_row3_col3" class="data row3 col3" >0.638639</td>
#       <td id="T_b305a_row3_col4" class="data row3 col4" >0.448170</td>
#       <td id="T_b305a_row3_col5" class="data row3 col5" >0.780989</td>
#       <td id="T_b305a_row3_col6" class="data row3 col6" >0.412797</td>
#       <td id="T_b305a_row3_col7" class="data row3 col7" >0.219011</td>
#       <td id="T_b305a_row3_col8" class="data row3 col8" >0.412797</td>
#       <td id="T_b305a_row3_col9" class="data row3 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_b305a_row3_col10" class="data row3 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_b305a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b305a_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_b305a_row4_col1" class="data row4 col1" >0.437128</td>
#       <td id="T_b305a_row4_col2" class="data row4 col2" >0.529745</td>
#       <td id="T_b305a_row4_col3" class="data row4 col3" >0.203900</td>
#       <td id="T_b305a_row4_col4" class="data row4 col4" >0.322613</td>
#       <td id="T_b305a_row4_col5" class="data row4 col5" >0.418355</td>
#       <td id="T_b305a_row4_col6" class="data row4 col6" >0.492529</td>
#       <td id="T_b305a_row4_col7" class="data row4 col7" >0.581645</td>
#       <td id="T_b305a_row4_col8" class="data row4 col8" >0.492529</td>
#       <td id="T_b305a_row4_col9" class="data row4 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_b305a_row4_col10" class="data row4 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_b305a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b305a_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_b305a_row5_col1" class="data row5 col1" >0.899285</td>
#       <td id="T_b305a_row5_col2" class="data row5 col2" >0.333016</td>
#       <td id="T_b305a_row5_col3" class="data row5 col3" >0.857452</td>
#       <td id="T_b305a_row5_col4" class="data row5 col4" >0.338778</td>
#       <td id="T_b305a_row5_col5" class="data row5 col5" >0.890346</td>
#       <td id="T_b305a_row5_col6" class="data row5 col6" >0.312552</td>
#       <td id="T_b305a_row5_col7" class="data row5 col7" >0.109654</td>
#       <td id="T_b305a_row5_col8" class="data row5 col8" >0.312552</td>
#       <td id="T_b305a_row5_col9" class="data row5 col9" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#       <td id="T_b305a_row5_

# %%
result_all_default.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_16dd4_row0_col1, #T_16dd4_row61_col1, #T_16dd4_row63_col7, #T_16dd4_row64_col1 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_16dd4_row8_col3, #T_16dd4_row29_col3, #T_16dd4_row40_col3 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_16dd4_row8_col5, #T_16dd4_row25_col5, #T_16dd4_row56_col3, #T_16dd4_row58_col3 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_16dd4_row8_col6, #T_16dd4_row8_col8, #T_16dd4_row22_col3, #T_16dd4_row24_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_16dd4_row9_col1, #T_16dd4_row44_col3, #T_16dd4_row70_col5, #T_16dd4_row71_col5, #T_16dd4_row74_col5 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_16dd4_row9_col3, #T_16dd4_row37_col6, #T_16dd4_row37_col8, #T_16dd4_row72_col5, #T_16dd4_row79_col1 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_16dd4_row9_col4, #T_16dd4_row44_col2, #T_16dd4_row55_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_16dd4_row9_col5, #T_16dd4_row43_col3, #T_16dd4_row67_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_16dd4_row9_col7, #T_16dd4_row44_col4 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_16dd4_row10_col1, #T_16dd4_row68_col4 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_

# %% [markdown]
# ## Texts in lowercase and removed special characters and punctuations

# %%
result_identity_card_lowercase_no_special['type'] = 'Identity Card'
result_IIIT5K_lowercase_no_special['type'] = 'IIIT5K'
result_filtered_SROEI_lowercase_no_special['type'] = 'SROEI'

result_no_special = pd.concat([result_identity_card_lowercase_no_special, result_IIIT5K_lowercase_no_special, result_filtered_SROEI_lowercase_no_special], ignore_index=True)

# %%
styled_df  = result_no_special.style.applymap(style_background_gradient, subset=['type'])
styled_df
# Out:
# <style type="text/css">
# #T_246c4_row0_col10, #T_246c4_row1_col10, #T_246c4_row2_col10, #T_246c4_row3_col10, #T_246c4_row4_col10, #T_246c4_row5_col10, #T_246c4_row6_col10, #T_246c4_row7_col10, #T_246c4_row8_col10, #T_246c4_row9_col10, #T_246c4_row10_col10, #T_246c4_row11_col10, #T_246c4_row12_col10, #T_246c4_row13_col10, #T_246c4_row14_col10, #T_246c4_row15_col10, #T_246c4_row16_col10, #T_246c4_row17_col10, #T_246c4_row18_col10, #T_246c4_row19_col10 {
#   background-color: red;
# }
# #T_246c4_row20_col10, #T_246c4_row21_col10, #T_246c4_row22_col10, #T_246c4_row23_col10, #T_246c4_row24_col10, #T_246c4_row25_col10, #T_246c4_row26_col10, #T_246c4_row27_col10, #T_246c4_row28_col10, #T_246c4_row29_col10, #T_246c4_row30_col10, #T_246c4_row31_col10, #T_246c4_row32_col10, #T_246c4_row33_col10, #T_246c4_row34_col10, #T_246c4_row35_col10, #T_246c4_row36_col10, #T_246c4_row37_col10, #T_246c4_row38_col10, #T_246c4_row39_col10 {
#   background-color: blue;
# }
# #T_246c4_row40_col10, #T_246c4_row41_col10, #T_246c4_row42_col10, #T_246c4_row43_col10, #T_246c4_row44_col10, #T_246c4_row45_col10, #T_246c4_row46_col10, #T_246c4_row47_col10, #T_246c4_row48_col10, #T_246c4_row49_col10, #T_246c4_row50_col10, #T_246c4_row51_col10, #T_246c4_row52_col10, #T_246c4_row53_col10, #T_246c4_row54_col10, #T_246c4_row55_col10, #T_246c4_row56_col10, #T_246c4_row57_col10, #T_246c4_row58_col10, #T_246c4_row59_col10 {
#   background-color: orange;
# }
# </style>
# <table id="T_246c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_246c4_level0_col0" class="col_heading level0 col0" >filter_</th>
#       <th id="T_246c4_level0_col1" class="col_heading level0 col1" >wer_no_schar_mean</th>
#       <th id="T_246c4_level0_col2" class="col_heading level0 col2" >wer_no_schar_std</th>
#       <th id="T_246c4_level0_col3" class="col_heading level0 col3" >cer_no_schar_mean</th>
#       <th id="T_246c4_level0_col4" class="col_heading level0 col4" >cer_no_schar_std</th>
#       <th id="T_246c4_level0_col5" class="col_heading level0 col5" >wil_no_schar_mean</th>
#       <th id="T_246c4_level0_col6" class="col_heading level0 col6" >wil_no_schar_std</th>
#       <th id="T_246c4_level0_col7" class="col_heading level0 col7" >wip_no_schar_mean</th>
#       <th id="T_246c4_level0_col8" class="col_heading level0 col8" >wip_no_schar_std</th>
#       <th id="T_246c4_level0_col9" class="col_heading level0 col9" >fluxo</th>
#       <th id="T_246c4_level0_col10" class="col_heading level0 col10" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_246c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_246c4_row0_col0" class="data row0 col0" >bilateral</td>
#       <td id="T_246c4_row0_col1" class="data row0 col1" >0.670644</td>
#       <td id="T_246c4_row0_col2" class="data row0 col2" >0.557283</td>
#       <td id="T_246c4_row0_col3" class="data row0 col3" >0.480576</td>
#       <td id="T_246c4_row0_col4" class="data row0 col4" >0.453708</td>
#       <td id="T_246c4_row0_col5" class="data row0 col5" >0.637828</td>
#       <td id="T_246c4_row0_col6" class="data row0 col6" >0.480461</td>
#       <td id="T_246c4_row0_col7" class="data row0 col7" >0.362172</td>
#       <td id="T_246c4_row0_col8" class="data row0 col8" >0.480461</td>
#       <td id="T_246c4_row0_col9" class="data row0 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_246c4_row0_col10" class="data row0 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_246c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_246c4_row1_col0" class="data row1 col0" >image_full_gray</td>
#       <td id="T_246c4_row1_col1" class="data row1 col1" >0.387232</td>
#       <td id="T_246c4_row1_col2" class="data row1 col2" >0.503828</td>
#       <td id="T_246c4_row1_col3" class="data row1 col3" >0.207280</td>
#       <td id="T_246c4_row1_col4" class="data row1 col4" >0.343640</td>
#       <td id="T_246c4_row1_col5" class="data row1 col5" >0.378431</td>
#       <td id="T_246c4_row1_col6" class="data row1 col6" >0.484563</td>
#       <td id="T_246c4_row1_col7" class="data row1 col7" >0.621569</td>
#       <td id="T_246c4_row1_col8" class="data row1 col8" >0.484563</td>
#       <td id="T_246c4_row1_col9" class="data row1 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_246c4_row1_col10" class="data row1 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_246c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_246c4_row2_col0" class="data row2 col0" >limiarização_binária</td>
#       <td id="T_246c4_row2_col1" class="data row2 col1" >0.707637</td>
#       <td id="T_246c4_row2_col2" class="data row2 col2" >0.509458</td>
#       <td id="T_246c4_row2_col3" class="data row2 col3" >0.523540</td>
#       <td id="T_246c4_row2_col4" class="data row2 col4" >0.448943</td>
#       <td id="T_246c4_row2_col5" class="data row2 col5" >0.686158</td>
#       <td id="T_246c4_row2_col6" class="data row2 col6" >0.464192</td>
#       <td id="T_246c4_row2_col7" class="data row2 col7" >0.313842</td>
#       <td id="T_246c4_row2_col8" class="data row2 col8" >0.464192</td>
#       <td id="T_246c4_row2_col9" class="data row2 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_246c4_row2_col10" class="data row2 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_246c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_246c4_row3_col0" class="data row3 col0" >limiarização_de_otsu</td>
#       <td id="T_246c4_row3_col1" class="data row3 col1" >0.765215</td>
#       <td id="T_246c4_row3_col2" class="data row3 col2" >0.484914</td>
#       <td id="T_246c4_row3_col3" class="data row3 col3" >0.618281</td>
#       <td id="T_246c4_row3_col4" class="data row3 col4" >0.450229</td>
#       <td id="T_246c4_row3_col5" class="data row3 col5" >0.745823</td>
#       <td id="T_246c4_row3_col6" class="data row3 col6" >0.435184</td>
#       <td id="T_246c4_row3_col7" class="data row3 col7" >0.254177</td>
#       <td id="T_246c4_row3_col8" class="data row3 col8" >0.435184</td>
#       <td id="T_246c4_row3_col9" class="data row3 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_246c4_row3_col10" class="data row3 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_246c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_246c4_row4_col0" class="data row4 col0" >original</td>
#       <td id="T_246c4_row4_col1" class="data row4 col1" >0.369630</td>
#       <td id="T_246c4_row4_col2" class="data row4 col2" >0.497315</td>
#       <td id="T_246c4_row4_col3" class="data row4 col3" >0.182213</td>
#       <td id="T_246c4_row4_col4" class="data row4 col4" >0.316255</td>
#       <td id="T_246c4_row4_col5" class="data row4 col5" >0.362172</td>
#       <td id="T_246c4_row4_col6" class="data row4 col6" >0.480461</td>
#       <td id="T_246c4_row4_col7" class="data row4 col7" >0.637828</td>
#       <td id="T_246c4_row4_col8" class="data row4 col8" >0.480461</td>
#       <td id="T_246c4_row4_col9" class="data row4 col9" >CRAFT -> OpenCV[todos preproc] -> EASYOCR</td>
#       <td id="T_246c4_row4_col10" class="data row4 col10" >Identity Card</td>
#     </tr>
#     <tr>
#       <th id="T_246c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_246c4_row5_col0" class="data row5 col0" >bilateral</td>
#       <td id="T_246c4_row5_col1" class="data row5 col1" >0.882458</td>
#       <td id="T_246c4_row5_col2" class="data row5 col2" >0.350560</td>
#       <td id="T_246c4_row5_col3" class="data row5 col3" >0.853875</td>
#       <td id="T_246c4_row5_col4" class="data row5 col4" >0.347647</td>
#       <td id="T_246c4_row5_col5" class="data row5 col5" >0.874105</td>
#       <td id="T_246c4_row5_col6" class="data row5 col6" >0.331830</td>
#       <td id="T_246c4_row5_col7" class="data row5 col7" >0.125895</td>
#       <td id="T_246c4_row5_col8" class="data row5 col8" >0.331830</td>
#       <td id="T_246c4_row5_col9" class="data row5 col9" >CRAFT -> OpenCV[todos preproc] -> Tesseract</td>
#       <td id="T_246c4_row5_col10" c

# %%
result_all_default.style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_87c26_row0_col1, #T_87c26_row61_col1, #T_87c26_row63_col7, #T_87c26_row64_col1 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_87c26_row0_col2, #T_87c26_row5_col7, #T_87c26_row10_col2, #T_87c26_row11_col2, #T_87c26_row26_col7, #T_87c26_row50_col2, #T_87c26_row51_col2, #T_87c26_row53_col2, #T_87c26_row54_col2, #T_87c26_row69_col7 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_87c26_row0_col3, #T_87c26_row16_col7, #T_87c26_row18_col7, #T_87c26_row30_col1, #T_87c26_row75_col3, #T_87c26_row79_col3 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T
{
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_87c26_row4_col1, #T_87c26_row40_col4, #T_87c26_row47_col6, #T_87c26_row47_col8 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_87c26_row4_col3, #T_87c26_row9_col2 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_87c26_row4_col4, #T_87c26_row65_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_87c26_row4_col5, #T_87c26_row7_col2, #T_87c26_row23_col4, #T_87c26_row27_col7, #T_87c26_row42_col4 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_87c26_row4_col7, #T_87c26_row27_col5 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# #T_87c26_row5_col1, #T_87c26_row16_col1, #T_87c26_row18_col1, #T_87c26_row66_col1, #T_87c26_row69_col1 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_87c26_row5_col2, #T_87c26_row10_col3, #T_87c26_row11_col1, #T_87c26_row65_col4 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_87c26_row5_col3, #T_87c26_row9_col6, #T_87c26_row9_col8, #T_87c26_row68_col3 {
#   background-color: #46c06f;
#   color: #f1f1f1;
# }
# #T_87c26_row5_col4, #T_87c26_row8_col4, #T_87c26_row11_col3, #T_87c26_row14_col1, #T_87c26_row14_col3, #T_87c26_row14_col5, #T_87c26_row40_col2, #T_87c26_row45_col6, #T_87c26_row45_col7, #T_87c26_row45_col8 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_87c26_row5_col6, #T_87c26_row5_col8, #T_87c26_row26_col6, #T_87c26_row26_col8 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_87c26_row6_col1, #T_87c26_row31_col7, #T_87c26_row34_col7, #T_87c26_row73_col5 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_87c26_row6_col2 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_87c26_row6_col3, #T_87c26_row77_col1 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_87c26_row6_col4, #T_87c26_row57_col7 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_87c26_row6_col5, #T_87c26_row26_col3, #T_87c26_row37_col3 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_87c26_row6_col7 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_87c26_row7_col1, #T_87c26_row19_col3, #T_87c26_row24_col7, #T_87c26_row28_col6, #T_87c26_row28_col8 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_87c26_row7_col3, #T_87c26_row32_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_87c26_row7_col4, #T_87c26_row8_col7, #T_87c26_row25_col7, #T_87c26_row49_col2, #T_87c26_row57_col4, #T_87c26_row62_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_87c26_row7_col5 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_87c26_row7_col6, #T_87c26_row7_col8, #T_87c26_row51_col7, #T_87c26_row61_col6, #T_87c26_row61_col8, #T_87c26_row64_col6, #T_87c26_row64_col8 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_87c26_row7_col7 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_87c26_row8_col1, #T_87c26_row15_col6, #T_87c26_row15_col8, #T_87c26_row63_col6, #T_87c26_row63_col8 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_87c26_row8_col3, #T_87c26_row29_col3, #T_87c26_row40_col3 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_87c26_row8_col5, #T_87c26_row25_col5, #T_87c26_row56_col3, #T_87c26_row58_col3 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_87c26_row8_col6, #T_87c26_row8_col8, #T_87c26_row22_col3, #T_87c26_row24_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_87c26_row9_col1, #T_87c26_row44_col3, #T_87c26_row70_col5, #T_87c26_row71_col5, #T_87c26_row74_col5 {
#   background-color: #1fa088;
#   color: #f1f1f1;
# }
# #T_87c26_row9_col3, #T_87c26_row37_col6, #T_87c26_row37_col8, #T_87c26_row72_col5, #T_87c26_row79_col1 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_87c26_row9_col4, #T_87c26_row44_col2, #T_87c26_row55_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_87c26_row9_col5, #T_87c26_row43_col3, #T_87c26_row67_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_87c26_row9_col7, #T_87c26_row44_col4 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_87c26_row10_col1, #T_87c26_row68_col4 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_
